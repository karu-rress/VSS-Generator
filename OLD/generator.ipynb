# %% [markdown]
# ## generator.ipynb
#
# Random VSS generator

# %%
# import necessary libraries
import json
import jsonpatch
import random

# %%
class vss_json:
    """VSS JSON manager class"""
        
    def __init__(self, **kwargs):
        """
        Initialize VSS JSON data
        
        :param kwargs: EITHER of the following is required
            - file: JSON file to load
            - data: JSON data (for internal use)
        """
        assert 'file' in kwargs or 'data' in kwargs
        self.initialized = False        
        
        if 'file' in kwargs:
            with open(kwargs['file'], 'r') as f:
                self.data = json.load(f)  
            self.remove_key('description', 'uuid', 'type', 'comment', 'deprecated')
        elif 'data' in kwargs:
            self.data = kwargs['data']
            self.initialized = True
        else:
            raise ValueError('Either file or data must be provided')
        
    def print(self, indent: int=4, with_index: bool=False) -> None:
        """Print JSON data"""
        txt = json.dumps(self.data, indent=indent)
        if with_index:
            for i, line in enumerate(txt.split('\n'), 1):
                print(f'{i:05d}: {line}')
        else:
            print(txt)
        
    def remove_key(self, *keys: str) -> None:
        """
        Remove keys from JSON data recursively
        
        :param keys: Keys to remove
        """
        for leaf, _ in self.leaf_nodes():
            for key in keys:
                if key in leaf:
                    del leaf[key]
            
    def leaf_nodes(self, data=None, parent_key=''):
        """
        Traverse and yield all leaf values (dict/scaler) in JSON data
        
        :param data: JSON data to traverse (default: self.data)
        :param parent_key: Parent key to track the hierarchy (for debugging and display purposes)
        """
        if data is None:
            data = self.data
        
        if not self.initialized:
            if isinstance(data, dict):
                is_leaf = all(not isinstance(value, dict) for value in data.values())
                if is_leaf:
                    yield data, parent_key
                else:
                    for key, value in data.items():
                        yield from self.leaf_nodes(value, parent_key + '.' + key if parent_key else key)
            elif isinstance(data, list):
                for index, item in enumerate(data):
                    yield from self.leaf_nodes(item, parent_key + f'[{index}]')
        else:
            if isinstance(data, dict):
                for key, value in data.items():
                    yield from self.leaf_nodes(value, parent_key + '.' + key if parent_key else key)
            elif isinstance(data, list):
                for index, item in enumerate(data):
                    yield data, parent_key
            else:
                yield data, parent_key
                
    
    def generate(self, dataset_size: float=1.0) -> 'vss_json':
        """
        Generate an initial random dataset based on the JSON schema
        
        :param dataset_size: Dataset size ratio [0.0, 1.0]
        """
        result = {}
        
        for leaf, parent in self.leaf_nodes():
            # !! only add the node by dataset_size
            if random.random() > dataset_size:
                continue
            
            # step 1: set parent (without 'children' dictionary)
            hierarchy = [x for x in parent.split('.') if x != 'children']
            new = result
            for idx, node in enumerate(hierarchy):
                if node not in new:
                    new[node] = {}
                    if idx == len(hierarchy) - 1:
                        break
                    new = new[node]
                
            # step 2: set leaf by 'datatype'
            dtype = leaf['datatype']
            if dtype == 'boolean':
                new[node] = random.choice([True, False])
            elif dtype in ['int8', 'uint8', 'float'] and \
                'unit' in leaf and leaf['unit'] == 'percent':
                new[node] = random.random() * 100
                if dtype != 'float':
                    new[node] = int(new[node])
            elif 'allowed' in leaf:
                new[node] = random.choice(leaf['allowed'])
            elif dtype == 'double' or dtype == 'float':
                new[node] = random.random() * 100
            elif dtype == 'float[]':
                new[node] = []
                for i in range(random.randint(1, 5)):
                    new[node].append(random.random() * 100)
            elif dtype in ['int8', 'int16', 'int32']:
                new[node] = random.randint(-100, 100)
            elif dtype == 'string':
                # generate random str`ing
                new[node] = ''.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=10))
            elif dtype == 'string[]':
                new[node] = []
                for i in range(random.randint(1, 5)):
                    new[node].append(''.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=10)))
            elif dtype in ['uint8', 'uint16', 'uint32']:
                new[node] = random.randint(0, 100)
            elif dtype == 'uint8[]':
                new[node] = []
                for i in range(random.randint(1, 5)):
                    new[node].append(random.randint(0, 100))
                    
            # step 3: set the leaf
        
        return vss_json(data=result)
    
    def generate_next(self, change_rate):
        assert self.initialized, 'vss_json must be initialized with generate()'
        
        result = {}
        for leaf_data, parent in self.leaf_nodes():
            hierarchy = [x for x in parent.split('.') if x != 'children']
            current = result
            for idx, node in enumerate(hierarchy):
                if node not in current:
                    current[node] = {}
                    if idx == len(hierarchy) - 1:
                        break
                    current = current[node]
                    
            if isinstance(leaf_data, list):
                current[node] = leaf_data[:]
                continue        
            
            if random.random() > change_rate:
                current[node] = leaf_data
                continue
            
            match leaf_data:
                case str():
                    current[node] = ''.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=10))
                case bool():
                    current[node] = not leaf_data
                case int():
                    current[node] = random.randint(0, 100)
                case float():
                    current[node] = random.random() * 100
        return vss_json(data=result), vss_json(data=jsonpatch.make_patch(self.data, result).patch)
    
    def save(self, file: str) -> None:
        """Save JSON data to file"""
        with open(file, 'w') as f:
            json.dump(self.data, f, indent=4)

# %%
vss = vss_json(file='../vss_rel_4.2.json')

# %%
# JSON 내용 확인
# vss.print(2, True)

# %%
# Generate initial random dataset
first = vss.generate(1.0)
first.print(2, True)
# Out:
# 00001: {
# 00002:   "Vehicle": {
# 00003:     "ADAS": {
# 00004:       "ABS": {
# 00005:         "IsEnabled": false
# 00006:       }
# 00007:     }
# 00008:   },
# 00009:   "ADAS": {
# 00010:     "ABS": {
# 00011:       "IsEngaged": false
# 00012:     }
# 00013:   },
# 00014:   "ABS": {
# 00015:     "IsError": true
# 00016:   },
# 00017:   "ActiveAutonomyLevel": "SAE_4",
# 00018:   "CruiseControl": {
# 00019:     "IsActive": false
# 00020:   },
# 00021:   "IsEnabled": false,
# 00022:   "IsError": false,
# 00023:   "SpeedSet": 28.16553862222514,
# 00024:   "DMS": {
# 00025:     "IsEnabled": false
# 00026:   },
# 00027:   "IsWarning": false,
# 00028:   "EBA": {
# 00029:     "IsEnabled": true
# 00030:   },
# 00031:   "IsEngaged": true,
# 00032:   "EBD": {
# 00033:     "IsEnabled": false
# 00034:   },
# 00035:   "ESC": {
# 00036:     "IsEnabled": false
# 00037:   },
# 00038:   "IsStrongCrossWindDetected": false,
# 00039:   "RoadFriction": {
# 00040:     "LowerBound": 60.92671858689817
# 00041:   },
# 00042:   "MostProbable": 99.074253428698,
# 00043:   "UpperBound": 73.10333009012552,
# 00044:   "IsAutoPowerOptimize": true,
# 00045:   "LaneDepartureDetection": {
# 00046:     "IsEnabled": true
# 00047:   },
# 00048:   "ObstacleDetection": {
# 00049:     "IsEnabled": true
# 00050:   },
# 00051:   "PowerOptimizeLevel": 21,
# 00052:   "SupportedAutonomyLevel": "SAE_3",
# 00053:   "TCS": {
# 00054:     "IsEnabled": true
# 00055:   },
# 00056:   "Acceleration": {
# 00057:     "Lateral": 28.99604012707956
# 00058:   },
# 00059:   "Longitudinal": 26.97276150830794,
# 00060:   "Vertical": 84.95776250444476,
# 00061:   "AngularVelocity": {
# 00062:     "Pitch": 63.29793600335698
# 00063:   },
# 00064:   "Roll": 82.30567840955133,
# 00065:   "Yaw": 88.85171733934298,
# 00066:   "AverageSpeed": 74.0381089006854,
# 00067:   "Body": {
# 00068:     "BodyType": "wsijcxtvjy"
# 00069:   },
# 00070:   "Hood": {
# 00071:     "IsOpen": false
# 00072:   },
# 00073:   "Position": 40,
# 00074:   "Switch": "OPEN",
# 00075:   "Horn": {
# 00076:     "IsActive": false
# 00077:   },
# 00078:   "Lights": {
# 00079:     "Backup": {
# 00080:       "IsDefect": false
# 00081:     }
# 00082:   },
# 00083:   "Backup": {
# 00084:     "IsOn": true
# 00085:   },
# 00086:   "Beam": {
# 00087:     "High": {
# 00088:       "IsDefect": true
# 00089:     }
# 00090:   },
# 00091:   "High": {
# 00092:     "IsOn": false
# 00093:   },
# 00094:   "Low": {
# 00095:     "IsDefect": false
# 00096:   },
# 00097:   "IsOn": false,
# 00098:   "Brake": {
# 00099:     "IsActive": "INACTIVE"
# 00100:   },
# 00101:   "IsDefect": false,
# 00102:   "DirectionIndicator": {
# 00103:     "Left": {
# 00104:       "IsDefect": false
# 00105:     }
# 00106:   },
# 00107:   "Left": {
# 00108:     "IsSignaling": false
# 00109:   },
# 00110:   "Right": {
# 00111:     "IsDefect": false
# 00112:   },
# 00113:   "IsSignaling": true,
# 00114:   "Fog": {
# 00115:     "Front": {
# 00116:       "IsDefect": false
# 00117:     }
# 00118:   },
# 00119:   "Front": {
# 00120:     "IsOn": false
# 00121:   },
# 00122:   "Rear": {
# 00123:     "IsDefect": true
# 00124:   },
# 00125:   "Hazard": {
# 00126:     "IsDefect": true
# 00127:   },
# 00128:   "IsHighBeamSwitchOn": true,
# 00129:   "LicensePlate": "eucoqpfrcj",
# 00130:   "LightSwitch": "OFF",
# 00131:   "Parking": {
# 00132:     "IsDefect": false
# 00133:   },
# 00134:   "Running": {
# 00135:     "IsDefect": false
# 00136:   },
# 00137:   "Mirrors": {
# 00138:     "DriverSide": {
# 00139:       "IsFolded": false
# 00140:     }
# 00141:   },
# 00142:   "DriverSide": {
# 00143:     "IsHeatingOn": true
# 00144:   },
# 00145:   "IsLocked": false,
# 00146:   "Pan": 98,
# 00147:   "Tilt": 54,
# 00148:   "PassengerSide": {
# 00149:     "IsFolded": true
# 00150:   },
# 00151:   "IsHeatingOn": false,
# 00152:   "Raindetection": {
# 00153:     "Intensity": 6
# 00154:   },
# 00155:   "RearMainSpoilerPosition": 68.64644739118776,
# 00156:   "RefuelPosition": "REAR_LEFT",
# 00157:   "Trunk": {
# 00158:     "Front": {
# 00159:       "IsLightOn": false
# 00160:     }
# 00161:   },
# 00162:   "IsOpen": true,
# 00163:   "IsLightOn": false,
# 00164:   "Windshield": {
# 00165:     "Front": {
# 00166:       "IsHeatingOn": false
# 00167:     }
# 00168:   },
# 00169:   "WasherFluid": {
# 00170:     "IsLevelLow": false
# 00171:   },
# 00172:   "Level": "NORMAL",
# 00173:   "Wiping": {
# 00174:     "Intensity": 8
# 00175:   },
# 00176:   "IsWipersWorn": false,
# 00177:   "Mode": "EXTERNAL_ENTITY",
# 00178:   "System": {
# 00179:     "ActualPosition": 24.874616950333873
# 00180:   },
# 00181:   "DriveCurrent": 51.55348348304057,
# 00182:   "Frequency": 79,
# 00183:   "IsBlocked": true,
# 00184:   "IsEndingWipeCycle": false,
# 00185:   "IsOverheated": true,
# 00186:   "IsPositionReached": true,
# 00187:   "IsWiperError": true,
# 00188:   "IsWiping": false,
# 00189:   "TargetPosition": 66.44271303261154,
# 00190:   "WiperWear": 81,
# 00191:   "IsLevelLow": false,
# 00192:   "Intensity": 14,
# 00193:   "ActualPosition": 64.19815031449914,
# 00194:   "Cabin": {
# 00195:     "Convertible": {
# 00196:       "Status": "STALLED"
# 00197:     }
# 00198:   },
# 00199:   "Door": {
# 00200:     "Row1": {
# 00201:       "DriverSide": {
# 00202:         "IsChildLockActive": false
# 00203:       }
# 00204:     }
# 00205:   },
# 00206:   "Row1": {
# 00207:     "DriverSide": {
# 00208:       "IsLocked": false
# 00209:     }
# 00210:   },
# 00211:   "Shade": {
# 00212:     "IsOpen": false
# 00213:   },
# 00214:   "Window": {
# 00215:     "IsOpen": true
# 00216:   },
# 00217:   "IsChildLockActive": false,
# 00218:   "Row2": {
# 00219:     "DriverSide": {
# 00220:       "IsChildLockActive": false
# 00221:     }
# 00222:   },
# 00223:   "DoorCount": 38,
# 00224:   "DriverPosition": "RIGHT",
# 00225:   "HVAC": {
# 00226:     "AmbientAirTemperature": 57.240785916271456
# 00227:   },
# 00228:   "IsAirConditioningActive": true,
# 00229:   "IsFrontDefrosterActive": true,
# 00230:   "IsRearDefrosterActive": false,
# 00231:   "IsRecirculationActive": false,
# 00232:   "Station": {
# 00233:     "Row1": {
# 00234:       "Driver": {
# 00235:         "AirDistribution": "DOWN"
# 00236:       }
# 00237:     }
# 00238:   },
# 00239:   "Driver": {
# 00240:     "FanSpeed": 87
# 00241:   },
# 00242:   "Temperature": 59,
# 00243:   "Passenger": {
# 00244:     "AirDistribution": "UP"
# 00245:   },
# 00246:   "FanSpeed": 17,
# 00247:   "AirDistribution": "UP",
# 00248:   "Row3": {
# 00249:     "Driver": {
# 00250:       "AirDistribution": "UP"
# 00251:     }
# 00252:   },
# 00253:   "Row4": {
# 00254:     "Driver": {
# 00255:       "AirDistribution": "DOWN"
# 00256:     }
# 00257:   },
# 00258:   "Infotainment": {
# 00259:     "HMI": {
# 00260:       "Brightness": 39.13821382075111
# 00261:     }
# 00262:   },
# 00263:   "HMI": {
# 00264:     "CurrentLanguage": "saeypmozoj"
# 00265:   },
# 00266:   "DateFormat": "YY_MM_DD",
# 00267:   "DayNightMode": "NIGHT",
# 00268:   "DisplayOffDuration": 41,
# 00269:   "DistanceUnit": "KILOMETERS",
# 00270:   "EVEconomyUnits": "MILES_PER_KILOWATT_HOUR",
# 00271:   "EVEnergyUnits": "AMPERE_HOURS",
# 00272:   "FontSize": "EXTRA_LARGE",
# 00273:   "FuelEconomyUnits": "MPG_UK",
# 00274:   "FuelVolumeUnit": "GALLON_US",
# 00275:   "IsScreenAlwaysOn": true,
# 00276:   "LastActionTime": "ecpgcevnsf",
# 00277:   "SpeedUnit": "METERS_PER_SECOND",
# 00278:   "TemperatureUnit": "C",
# 00279:   "TimeFormat": "HR_12",
# 00280:   "TirePressureUnit": "PSI",
# 00281:   "Media": {
# 00282:     "Action": "SKIP_BACKWARD"
# 00283:   },
# 00284:   "DeclinedURI": "niybwrbqvj",
# 00285:   "Played": {
# 00286:     "Album": "expiuzvrqq"
# 00287:   },
# 00288:   "Artist": "mtjvczlwtu",
# 00289:   "PlaybackRate": 2.4539166185576833,
# 00290:   "Source": "BLUETOOTH",
# 00291:   "Track": "cmjrydnwog",
# 00292:   "URI": "sbadudgpet",
# 00293:   "SelectedURI": "bcxfruater",
# 00294:   "Volume": 80,
# 00295:   "Navigation": {
# 00296:     "DestinationSet": {
# 00297:       "Latitude": 75.65281747710316
# 00298:     }
# 00299:   },
# 00300:   "DestinationSet": {
# 00301:     "Longitude": 21.38146389165625
# 00302:   },
# 00303:   "GuidanceVoice": "ETC",
# 00304:   "Map": {
# 00305:     "IsAutoScaleModeUsed": false
# 00306:   },
# 00307:   "Mute": "UNMUTED",
# 00308:   "SmartphoneProjection": {
# 00309:     "Active": "NONE"
# 00310:   },
# 00311:   "SupportedMode": "MIRROR_LINK",
# 00312:   "SmartphoneScreenMirroring": {
# 00313:     "Active": "INACTIVE"
# 00314:   },
# 00315:   "IsWindowChildLockEngaged": true,
# 00316:   "Light": {
# 00317:     "AmbientLight": {
# 00318:       "Row1": {
# 00319:         "DriverSide": {
# 00320:           "Color": "ngssadkftp"
# 00321:         }
# 00322:       }
# 00323:     }
# 00324:   },
# 00325:   "AmbientLight": {
# 00326:     "Row1": {
# 00327:       "DriverSide": {
# 00328:         "Intensity": 82
# 00329:       }
# 00330:     }
# 00331:   },
# 00332:   "Color": "qwnqsvjqdg",
# 00333:   "InteractiveLightBar": {
# 00334:     "Color": "siiyioxrwk"
# 00335:   },
# 00336:   "Effect": "sawsmgrilu",
# 00337:   "IsDomeOn": true,
# 00338:   "IsGloveBoxOn": false,
# 00339:   "PerceivedAmbientLight": 8,
# 00340:   "Spotlight": {
# 00341:     "Row1": {
# 00342:       "DriverSide": {
# 00343:         "Color": "wvqlzxsyjw"
# 00344:       }
# 00345:     }
# 00346:   },
# 00347:   "RearShade": {
# 00348:     "IsOpen": true
# 00349:   },
# 00350:   "RearviewMirror": {
# 00351:     "DimmingLevel": 7
# 00352:   },
# 00353:   "Seat": {
# 00354:     "Row1": {
# 00355:       "DriverSide": {
# 00356:         "Airbag": {
# 00357:           "IsDeployed": true
# 00358:         }
# 00359:       }
# 00360:     }
# 00361:   },
# 00362:   "Backrest": {
# 00363:     "Lumbar": {
# 00364:       "Height": 97
# 00365:     }
# 00366:   },
# 00367:   "Lumbar": {
# 00368:     "Support": 41.58095317316144
# 00369:   },
# 00370:   "Recline": 80.18665559010121,
# 00371:   "SideBolster": {
# 00372:     "Support": 35.127393156300066
# 00373:   },
# 00374:   "Headrest": {
# 00375:     "Angle": 16.801299026728046
# 00376:   },
# 00377:   "Height": 24,
# 00378:   "Heating": 93,
# 00379:   "HeatingCooling": 56,
# 00380:   "IsBelted": false,
# 00381:   "IsOccupied": false,
# 00382:   "Massage": 88,
# 00383:   "Occupant": {
# 00384:     "Identifier": {
# 00385:       "Issuer": "kupazbqffp"
# 00386:     }
# 00387:   },
# 00388:   "Identifier": {
# 00389:     "Subject": "tmkvcxwccu"
# 00390:   },
# 00391:   "SeatBeltHeight": 83,
# 00392:   "Seating": {
# 00393:     "Length": 73
# 00394:   },
# 00395:   "IsReclineBackwardEngaged": false,
# 00396:   "IsReclineForwardEngaged": true,
# 00397:   "IsDownEngaged": true,
# 00398:   "IsLessSupportEngaged": false,
# 00399:   "IsMoreSupportEngaged": true,
# 00400:   "IsUpEngaged": true,
# 00401:   "IsBackwardEngaged": false,
# 00402:   "IsForwardEngaged": true,
# 00403:   "IsCoolerEngaged": true,
# 00404:   "IsTiltBackwardEngaged": false,
# 00405:   "IsTiltForwardEngaged": false,
# 00406:   "IsWarmerEngaged": false,
# 00407:   "IsDecreaseEngaged": false,
# 00408:   "IsIncreaseEngaged": false,
# 00409:   "Middle": {
# 00410:     "Airbag": {
# 00411:       "IsDeployed": true
# 00412:     }
# 00413:   },
# 00414:   "Support": 72.30164412590584,
# 00415:   "Angle": 12.083433708220303,
# 00416:   "Issuer": "fcrbfiinlr",
# 00417:   "Subject": "kkkqxcnunz",
# 00418:   "Length": 42,
# 00419:   "Airbag": {
# 00420:     "IsDeployed": false
# 00421:   },
# 00422:   "IsDeployed": false,
# 00423:   "SeatPosCount": [
# 00424:     88,
# 00425:     53,
# 00426:     34,
# 00427:     24,
# 00428:     43
# 00429:   ],
# 00430:   "SeatRowCount": 48,
# 00431:   "Sunroof": {
# 00432:     "Position": 75
# 00433:   },
# 00434:   "CargoVolume": 62.03728052918882,
# 00435:   "Chassis": {
# 00436:     "Accelerator": {
# 00437:       "PedalPosition": 72
# 00438:     }
# 00439:   },
# 00440:   "Axle": {
# 00441:     "Row1": {
# 00442:       "AxleWidth": 3
# 00443:     }
# 00444:   },
# 00445:   "SteeringAngle": 55.61897147138498,
# 00446:   "TireAspectRatio": 76,
# 00447:   "TireDiameter": 26.08972495218541,
# 00448:   "TireWidth": 64,
# 00449:   "TrackWidth": 19,
# 00450:   "TreadWidth": 98,
# 00451:   "Wheel": {
# 00452:     "Left": {
# 00453:       "AngularSpeed": 43.45230284699571
# 00454:     }
# 00455:   },
# 00456:   "FluidLevel": 60,
# 00457:   "IsBrakesWorn": false,
# 00458:   "IsFluidLevelLow": false,
# 00459:   "PadWear": 81,
# 00460:   "Speed": 11.464672472490001,
# 00461:   "Tire": {
# 00462:     "IsPressureLow": false
# 00463:   },
# 00464:   "Pressure": 68,
# 00465:   "AngularSpeed": 34.97000565634705,
# 00466:   "IsPressureLow": false,
# 00467:   "WheelCount": 17,
# 00468:   "WheelDiameter": 0.3728936017711737,
# 00469:   "WheelWidth": 36.422649211907434,
# 00470:   "AxleWidth": 62,
# 00471:   "AxleCount": 82,
# 00472:   "IsDriverEmergencyBrakingDetected": true,
# 00473:   "PedalPosition": 35,
# 00474:   "ParkingBrake": {
# 00475:     "IsAutoApplyEnabled": true
# 00476:   },
# 00477:   "SteeringWheel": {
# 00478:     "Angle": -75
# 00479:   },
# 00480:   "Extension": 5,
# 00481:   "Wheelbase": 66,
# 00482:   "Connectivity": {
# 00483:     "IsConnectivityAvailable": true
# 00484:   },
# 00485:   "CurbWeight": 20,
# 00486:   "CurrentLocation": {
# 00487:     "Altitude": 8.361711495783354
# 00488:   },
# 00489:   "GNSSReceiver": {
# 00490:     "FixType": "THREE_D_SATELLITE_BASED_AUGMENTATION"
# 00491:   },
# 00492:   "MountingPosition": {
# 00493:     "X": -94
# 00494:   },
# 00495:   "Y": -72,
# 00496:   "Z": 25,
# 00497:   "Heading": 15.424757997775028,
# 00498:   "HorizontalAccuracy": 74.98210036058069,
# 00499:   "Latitude": 96.6537642616658,
# 00500:   "Longitude": 10.206856597888347,
# 00501:   "Timestamp": "twladakjtj",
# 00502:   "VerticalAccuracy": 96.43264163896376,
# 00503:   "CurrentOverallWeight": 31,
# 00504:   "Diagnostics": {
# 00505:     "DTCCount": 38
# 00506:   },
# 00507:   "DTCList": [
# 00508:     "gcilajzspp",
# 00509:     "mflohyzihr",
# 00510:     "uoqmeypqos",
# 00511:     "xmthjlopvv"
# 00512:   ],
# 00513:   "AttentiveProbability": 25.49283483195417,
# 00514:   "DistractionLevel": 62.43498937711276,
# 00515:   "FatigueLevel": 8.389403003911966,
# 00516:   "HeartRate": 12,
# 00517:   "IsEyesOnRoad": true,
# 00518:   "IsHandsOnWheel": true,
# 00519:   "EmissionsCO2": 61,
# 00520:   "Exterior": {
# 00521:     "AirTemperature": 16.759975677345253
# 00522:   },
# 00523:   "Humidity": 41.65818991346741,
# 00524:   "LightIntensity": 83.3519412808265,
# 00525:   "GrossWeight": 62,
# 00526:   "IsBrokenDown": false,
# 00527:   "IsMoving": false,
# 00528:   "LowVoltageBattery": {
# 00529:     "CurrentCurrent": 75.00682918979147
# 00530:   },
# 00531:   "CurrentVoltage": 68.65390442268648,
# 00532:   "NominalCapacity": 74,
# 00533:   "NominalVoltage": 12,
# 00534:   "LowVoltageSystemState": "ON",
# 00535:   "MaxTowBallWeight": 17,
# 00536:   "MaxTowWeight": 80,
# 00537:   "OBD": {
# 00538:     "AbsoluteLoad": 80.42737852532322
# 00539:   },
# 00540:   "AcceleratorPositionD": 80.40270257701063,
# 00541:   "AcceleratorPositionE": 51.93821579314225,
# 00542:   "AcceleratorPositionF": 45.42419444908234,
# 00543:   "AirStatus": "wjjkztcxjp",
# 00544:   "AmbientAirTemperature": 35.502553325058614,
# 00545:   "BarometricPressure": 90.46237685675112,
# 00546:   "Catalyst": {
# 00547:     "Bank1": {
# 00548:       "Temperature1": 10.255599355885392
# 00549:     }
# 00550:   },
# 00551:   "Bank1": {
# 00552:     "Temperature2": 14.436700415862125
# 00553:   },
# 00554:   "Bank2": {
# 00555:     "Temperature1": 99.59365626176549
# 00556:   },
# 00557:   "Temperature2": 55.468220056237136,
# 00558:   "CommandedEGR": 51.36358157793356,
# 00559:   "CommandedEVAP": 26.080874508656738,
# 00560:   "CommandedEquivalenceRatio": 85.34343996166493,
# 00561:   "ControlModuleVoltage": 31.755507984380817,
# 00562:   "CoolantTemperature": 71.96877781603862,
# 00563:   "DistanceSinceDTCClear": 11.694808812785363,
# 00564:   "DistanceWithMIL": 56.78351511254035,
# 00565:   "DriveCycleStatus": {
# 00566:     "DTCCount": 63
# 00567:   },
# 00568:   "IgnitionType": "SPARK",
# 00569:   "IsMILOn": true,
# 00570:   "EGRError": 7.785025038798288,
# 00571:   "EVAPVaporPressure": 10.695701328387585,
# 00572:   "EVAPVaporPressureAbsolute": 70.58357279919257,
# 00573:   "EVAPVaporPressureAlternate": 37.391440712715976,
# 00574:   "EngineLoad": 70.79760543972827,
# 00575:   "EngineSpeed": 32.69852312594139,
# 00576:   "EthanolPercent": 68.0601324118383,
# 00577:   "FreezeDTC": "kkhqwqfrwc",
# 00578:   "FuelInjectionTiming": 66.29234680245557,
# 00579:   "FuelLevel": 19.22954180710623,
# 00580:   "FuelPressure": 31.797543522158435,
# 00581:   "FuelRailPressureAbsolute": 22.083573204062002,
# 00582:   "FuelRailPressureDirect": 96.92376587595662,
# 00583:   "FuelRailPressureVac": 75.7966383737042,
# 00584:   "FuelRate": 67.36836259669857,
# 00585:   "FuelStatus": "emrtcggzte",
# 00586:   "FuelType": 74,
# 00587:   "HybridBatteryRemaining": 36.43422163285881,
# 00588:   "IntakeTemp": 39.017411121309934,
# 00589:   "IsPTOActive": false,
# 00590:   "LongTermFuelTrim1": 92.95690423623346,
# 00591:   "LongTermFuelTrim2": 32.667333748908575,
# 00592:   "LongTermO2Trim1": 50.84658686022775,
# 00593:   "LongTermO2Trim2": 66.0456980818315,
# 00594:   "LongTermO2Trim3": 12.946100890486656,
# 00595:   "LongTermO2Trim4": 77.50675799591971,
# 00596:   "MAF": 27,
# 00597:   "MAP": 60,
# 00598:   "MaxMAF": 98.70464610198744,
# 00599:   "O2": {
# 00600:     "Sensor1": {
# 00601:       "ShortTermFuelTrim": 75.08635462570976
# 00602:     }
# 00603:   },
# 00604:   "Sensor1": {
# 00605:     "Voltage": 23.098957450964786
# 00606:   },
# 00607:   "Sensor2": {
# 00608:     "ShortTermFuelTrim": 64.57452707747348
# 00609:   },
# 00610:   "Voltage": 12.30944548531534,
# 00611:   "Sensor3": {
# 00612:     "ShortTermFuelTrim": 45.882791352128294
# 00613:   },
# 00614:   "Sensor4": {
# 00615:     "ShortTermFuelTrim": 16.092786703514516
# 00616:   },
# 00617:   "Sensor5": {
# 00618:     "ShortTermFuelTrim": 92.34360346511788
# 00619:   },
# 00620:   "Sensor6": {
# 00621:     "ShortTermFuelTrim": 90.01052427687458
# 00622:   },
# 00623:   "Sensor7": {
# 00624:     "ShortTermFuelTrim": 73.26570681248478
# 00625:   },
# 00626:   "Sensor8": {
# 00627:     "ShortTermFuelTrim": 45.32076989523258
# 00628:   },
# 00629:   "O2WR": {
# 00630:     "Sensor1": {
# 00631:       "Current": 74.27587030390978
# 00632:     }
# 00633:   },
# 00634:   "Lambda": 41.270422904056915,
# 00635:   "Current": 62.986327174168736,
# 00636:   "OBDStandards": 7,
# 00637:   "OilTemperature": 58.00800562649528,
# 00638:   "OxygenSensorsIn2Banks": 53,
# 00639:   "OxygenSensorsIn4Banks": 3,
# 00640:   "PidsA": "01",
# 00641:   "PidsB": "24",
# 00642:   "PidsC": "5B",
# 00643:   "RelativeAcceleratorPosition": 22.974781472366956,
# 00644:   "RelativeThrottlePosition": 12.193586648130095,
# 00645:   "RunTime": 41.04500566586774,
# 00646:   "RunTimeMIL": 76.27854984548082,
# 00647:   "ShortTermFuelTrim1": 73.84648894619514,
# 00648:   "ShortTermFuelTrim2": 18.150972569632316,
# 00649:   "ShortTermO2Trim1": 14.235645428061295,
# 00650:   "ShortTermO2Trim2": 40.80778210487265,
# 00651:   "ShortTermO2Trim3": 4.777152065034851,
# 00652:   "ShortTermO2Trim4": 70.54706049101769,
# 00653:   "Status": {
# 00654:     "DTCCount": 94
# 00655:   },
# 00656:   "ThrottleActuator": 21.70114886198381,
# 00657:   "ThrottlePosition": 15.041257768946947,
# 00658:   "ThrottlePositionB": 56.830190684405416,
# 00659:   "ThrottlePositionC": 63.6492522983607,
# 00660:   "TimeSinceDTCCleared": 75.50629431202377,
# 00661:   "TimingAdvance": 2.689091153213574,
# 00662:   "WarmupsSinceDTCClear": 81,
# 00663:   "HeadPosition": {
# 00664:     "Pitch": 7.036603099907934
# 00665:   },
# 00666:   "X": -17,
# 00667:   "MidEyeGaze": {
# 00668:     "Azimuth": 35.10415035019191
# 00669:   },
# 00670:   "Elevation": 99.46715326067614,
# 00671:   "Pitch": 97.06231512519572,
# 00672:   "Azimuth": 82.00127152514577,
# 00673:   "Powertrain": {
# 00674:     "AccumulatedBrakingEnergy": 90.59469984457142
# 00675:   },
# 00676:   "CombustionEngine": {
# 00677:     "AspirationType": "UNKNOWN"
# 00678:   },
# 00679:   "Bore": 81.33038500152998,
# 00680:   "CompressionRatio": "qutoslvbvv",
# 00681:   "Configuration": "V",
# 00682:   "DieselExhaustFluid": {
# 00683:     "Capacity": 17.47422654162588
# 00684:   },
# 00685:   "Range": 55,
# 00686:   "DieselParticulateFilter": {
# 00687:     "DeltaPressure": 8.725874188647465
# 00688:   },
# 00689:   "InletTemperature": 12.47279288653953,
# 00690:   "OutletTemperature": 32.883742721673435,
# 00691:   "Displacement": 20,
# 00692:   "ECT": 36,
# 00693:   "EOP": 65,
# 00694:   "EOT": -33,
# 00695:   "EngineCode": "qcodabqiko",
# 00696:   "EngineCoolant": {
# 00697:     "Capacity": 36.19552125448146
# 00698:   },
# 00699:   "LifeRemaining": -41,
# 00700:   "EngineCoolantCapacity": 95.33090277785325,
# 00701:   "EngineHours": 48.22090237770056,
# 00702:   "EngineOil": {
# 00703:     "Capacity": 75.32878919097779
# 00704:   },
# 00705:   "EngineOilCapacity": 93.42886293050171,
# 00706:   "EngineOilLevel": "LOW",
# 00707:   "IdleHours": 17.40860327642284,
# 00708:   "IsRunning": false,
# 00709:   "MaxPower": 46.51790964344838,
# 00710:   "MaxTorque": 34,
# 00711:   "NumberOfCylinders": 46,
# 00712:   "NumberOfValvesPerCylinder": 67,
# 00713:   "OilLifeRemaining": -10,
# 00714:   "Power": 85,
# 00715:   "StrokeLength": 47.026631911588936,
# 00716:   "TPS": 2,
# 00717:   "Torque": 77,
# 00718:   "ElectricMotor": {
# 00719:     "CoolantTemperature": 100
# 00720:   },
# 00721:   "Capacity": 80.67590538225134,
# 00722:   "MaxRegenPower": 15,
# 00723:   "MaxRegenTorque": 69,
# 00724:   "TimeInUse": 50.17027036188281,
# 00725:   "FuelSystem": {
# 00726:     "AbsoluteLevel": 8.604291398889396
# 00727:   },
# 00728:   "AverageConsumption": 74.91014368856966,
# 00729:   "ConsumptionSinceStart": 93.56572267766474,
# 00730:   "HybridType": "CIMG",
# 00731:   "InstantConsumption": 73.24348189854192,
# 00732:   "IsEngineStopStartEnabled": false,
# 00733:   "IsFuelLevelLow": true,
# 00734:   "IsFuelPortFlapOpen": false,
# 00735:   "RefuelPortPosition": "FRONT_LEFT",
# 00736:   "RelativeLevel": 24,
# 00737:   "SupportedFuel": "E10_98",
# 00738:   "SupportedFuelTypes": "DIESEL",
# 00739:   "TankCapacity": 7.715347313314314,
# 00740:   "TimeRemaining": 37,
# 00741:   "TractionBattery": {
# 00742:     "AccumulatedChargedEnergy": 62.509028994064295
# 00743:   },
# 00744:   "AccumulatedChargedThroughput": 23.18311216280363,
# 00745:   "AccumulatedConsumedEnergy": 52.77517789388085,
# 00746:   "AccumulatedConsumedThroughput": 9.228118344210035,
# 00747:   "BatteryConditioning": {
# 00748:     "IsActive": false
# 00749:   },
# 00750:   "IsOngoing": true,
# 00751:   "RequestedMode": "DRIVING_PREPARATION",
# 00752:   "StartTime": "qxstrqwivv",
# 00753:   "TargetTemperature": 88.14995090875227,
# 00754:   "TargetTime": "bcnizaxfae",
# 00755:   "CellVoltage": {
# 00756:     "CellVoltages": [
# 00757:       2.1653647865574333,
# 00758:       33.754007941010386,
# 00759:       41.21457838319723,
# 00760:       30.532539793715095,
# 00761:       69.5738006491624
# 00762:     ]
# 00763:   },
# 00764:   "IdMax": 20,
# 00765:   "IdMin": 26,
# 00766:   "Max": 6.576400786082015,
# 00767:   "Min": 66.75661731599617,
# 00768:   "Charging": {
# 00769:     "AveragePower": 34.217490571260434
# 00770:   },
# 00771:   "ChargeCurrent": {
# 00772:     "DC": 98.62666559054604
# 00773:   },
# 00774:   "Phase1": 68.38664697717587,
# 00775:   "Phase2": 87.86021828316589,
# 00776:   "Phase3": 62.27857823747248,
# 00777:   "ChargeLimit": 68,
# 00778:   "ChargePlugType": "IEC_TYPE_4_DC",
# 00779:   "ChargePortFlap": "OPEN",
# 00780:   "ChargePortPosition": "LEFT_REAR",
# 00781:   "ChargePortType": "IEC_TYPE_3_AC",
# 00782:   "ChargeRate": 97.78445473370496,
# 00783:   "ChargeVoltage": {
# 00784:     "DC": 72.3801018801692
# 00785:   },
# 00786:   "EvseId": "zkomkaitkz",
# 00787:   "IsChargePortFlapOpen": true,
# 00788:   "IsCharging": true,
# 00789:   "IsChargingCableConnected": false,
# 00790:   "IsChargingCableLocked": false,
# 00791:   "IsDischarging": false,
# 00792:   "Location": {
# 00793:     "Altitude": 59.26618495705254
# 00794:   },
# 00795:   "MaximumChargingCurrent": {
# 00796:     "DC": 75.76702317113792
# 00797:   },
# 00798:   "PowerLoss": 51.24763891517031,
# 00799:   "StartStopCharging": "STOP",
# 00800:   "TimeToComplete": 39,
# 00801:   "Timer": {
# 00802:     "Mode": "START_TIME"
# 00803:   },
# 00804:   "Time": "dlzmnmeyqy",
# 00805:   "CurrentCurrent": 23.07322155830799,
# 00806:   "CurrentPower": 33.69061532827833,
# 00807:   "DCDC": {
# 00808:     "PowerLoss": 75.64452870276035
# 00809:   },
# 00810:   "ErrorCodes": [
# 00811:     "pfczieygsh",
# 00812:     "hfxyvhidcq"
# 00813:   ],
# 00814:   "GrossCapacity": 76,
# 00815:   "Id": "mexwngnjfa",
# 00816:   "IsGroundConnected": false,
# 00817:   "IsPowerConnected": false,
# 00818:   "MaxVoltage": 85,
# 00819:   "NetCapacity": 30,
# 00820:   "ProductionDate": "ifccquxdrr",
# 00821:   "StateOfCharge": {
# 00822:     "Current": 93.9962310313489
# 00823:   },
# 00824:   "CurrentEnergy": 87.15677317836307,
# 00825:   "Displayed": 81.98796712069336,
# 00826:   "StateOfHealth": 9.649840768015217,
# 00827:   "Average": 85.72201024390506,
# 00828:   "CellTemperature": [
# 00829:     33.01014699788571,
# 00830:     14.470358323872311,
# 00831:     62.53688414781169,
# 00832:     82.25135037383093
# 00833:   ],
# 00834:   "Transmission": {
# 00835:     "ClutchEngagement": 75.31857526876951
# 00836:   },
# 00837:   "ClutchWear": 9,
# 00838:   "CurrentGear": 97,
# 00839:   "DiffLockFrontEngagement": 33.37183261965504,
# 00840:   "DiffLockRearEngagement": 36.076801816246885,
# 00841:   "DriveType": "ALL_WHEEL_DRIVE",
# 00842:   "GearChangeMode": "AUTOMATIC",
# 00843:   "GearCount": 43,
# 00844:   "IsElectricalPowertrainEngaged": false,
# 00845:   "IsLowRangeEngaged": false,
# 00846:   "IsParkLockEngaged": true,
# 00847:   "PerformanceMode": "NORMAL",
# 00848:   "SelectedGear": 79,
# 00849:   "TorqueDistribution": 80.13175342285135,
# 00850:   "TravelledDistance": 9.584313316591142,
# 00851:   "Type": "ELECTRIC",
# 00852:   "RoofLoad": -61,
# 00853:   "Service": {
# 00854:     "DistanceToService": 73.99341010985675
# 00855:   },
# 00856:   "IsServiceDue": false,
# 00857:   "TimeToService": 31,
# 00858:   "Trailer": {
# 00859:     "IsConnected": false
# 00860:   },
# 00861:   "TraveledDistance": 96.29542721822662,
# 00862:   "TraveledDistanceSinceStart": 42.10558043489064,
# 00863:   "TripDuration": 51.131712173740965,
# 00864:   "TripMeterReading": 35.01806503068507,
# 00865:   "TurningDiameter": 74,
# 00866:   "VehicleIdentification": {
# 00867:     "AcrissCode": "gdwldzzaxw"
# 00868:   },
# 00869:   "BodyType": "qokkfintkl",
# 00870:   "Brand": "wunthiuqoh",
# 00871:   "DateVehicleFirstRegistered": "uxtojugcku",
# 00872:   "KnownVehicleDamages": "ymzzjszrrq",
# 00873:   "MeetsEmissionStandard": "emfjgfeyst",
# 00874:   "Model": "ihngnetxgj",
# 00875:   "OptionalExtras": [
# 00876:     "blmmqfhhtl",
# 00877:     "extooqfzdg",
# 00878:     "qiqwmmwzvu"
# 00879:   ],
# 00880:   "PurchaseDate": "peajaysffc",
# 00881:   "VIN": "nessjpckog",
# 00882:   "VehicleConfiguration": "vnrbpgvjzx",
# 00883:   "VehicleExteriorColor": "pxlzeovcjk",
# 00884:   "VehicleInteriorColor": "whxjefvxpl",
# 00885:   "VehicleInteriorType": "ntknmbqxba",
# 00886:   "VehicleModelDate": "wvoungamcc",
# 00887:   "VehicleSeatingCapacity": 94,
# 00888:   "VehicleSpecialUsage": "ivoxuelfmm",
# 00889:   "WMI": "hzwygekrnb",
# 00890:   "Year": 72,
# 00891:   "VersionVSS": {
# 00892:     "Label": "rhpidntiog"
# 00893:   },
# 00894:   "Major": 1,
# 00895:   "Minor": 76,
# 00896:   "Patch": 83,
# 00897:   "Width": 85,
# 00898:   "WidthExcludingMirrors": 93,
# 00899:   "WidthFoldedMirrors": 10,
# 00900:   "WidthIncludingMirrors": 23
# 00901: }

# %%
# Generate random subset (if required)
# small = vss.generate(0.005)
# small.print(2, True)

# %%
# Generate next random dataset based on initial one
# 0.2 : 20% of the data will be changed
second, patch = first.generate_next(0.2)
second.print(2, True)
# Out:
# 00001: {
# 00002:   "Vehicle": {
# 00003:     "ADAS": {
# 00004:       "ABS": {
# 00005:         "IsEnabled": false
# 00006:       }
# 00007:     }
# 00008:   },
# 00009:   "ADAS": {
# 00010:     "ABS": {
# 00011:       "IsEngaged": false
# 00012:     }
# 00013:   },
# 00014:   "ABS": {
# 00015:     "IsError": true
# 00016:   },
# 00017:   "ActiveAutonomyLevel": "SAE_4",
# 00018:   "CruiseControl": {
# 00019:     "IsActive": true
# 00020:   },
# 00021:   "IsEnabled": true,
# 00022:   "IsError": false,
# 00023:   "SpeedSet": 28.16553862222514,
# 00024:   "DMS": {
# 00025:     "IsEnabled": false
# 00026:   },
# 00027:   "IsWarning": false,
# 00028:   "EBA": {
# 00029:     "IsEnabled": true
# 00030:   },
# 00031:   "IsEngaged": true,
# 00032:   "EBD": {
# 00033:     "IsEnabled": false
# 00034:   },
# 00035:   "ESC": {
# 00036:     "IsEnabled": true
# 00037:   },
# 00038:   "IsStrongCrossWindDetected": false,
# 00039:   "RoadFriction": {
# 00040:     "LowerBound": 34.68654028185373
# 00041:   },
# 00042:   "MostProbable": 99.074253428698,
# 00043:   "UpperBound": 73.10333009012552,
# 00044:   "IsAutoPowerOptimize": true,
# 00045:   "LaneDepartureDetection": {
# 00046:     "IsEnabled": false
# 00047:   },
# 00048:   "ObstacleDetection": {
# 00049:     "IsEnabled": true
# 00050:   },
# 00051:   "PowerOptimizeLevel": 63,
# 00052:   "SupportedAutonomyLevel": "SAE_3",
# 00053:   "TCS": {
# 00054:     "IsEnabled": true
# 00055:   },
# 00056:   "Acceleration": {
# 00057:     "Lateral": 28.99604012707956
# 00058:   },
# 00059:   "Longitudinal": 80.38981574991556,
# 00060:   "Vertical": 84.95776250444476,
# 00061:   "AngularVelocity": {
# 00062:     "Pitch": 78.28293945240141
# 00063:   },
# 00064:   "Roll": 82.30567840955133,
# 00065:   "Yaw": 88.85171733934298,
# 00066:   "AverageSpeed": 13.50799931551563,
# 00067:   "Body": {
# 00068:     "BodyType": "wsijcxtvjy"
# 00069:   },
# 00070:   "Hood": {
# 00071:     "IsOpen": false
# 00072:   },
# 00073:   "Position": 40,
# 00074:   "Switch": "OPEN",
# 00075:   "Horn": {
# 00076:     "IsActive": false
# 00077:   },
# 00078:   "Lights": {
# 00079:     "Backup": {
# 00080:       "IsDefect": false
# 00081:     }
# 00082:   },
# 00083:   "Backup": {
# 00084:     "IsOn": false
# 00085:   },
# 00086:   "Beam": {
# 00087:     "High": {
# 00088:       "IsDefect": true
# 00089:     }
# 00090:   },
# 00091:   "High": {
# 00092:     "IsOn": false
# 00093:   },
# 00094:   "Low": {
# 00095:     "IsDefect": false
# 00096:   },
# 00097:   "IsOn": false,
# 00098:   "Brake": {
# 00099:     "IsActive": "INACTIVE"
# 00100:   },
# 00101:   "IsDefect": true,
# 00102:   "DirectionIndicator": {
# 00103:     "Left": {
# 00104:       "IsDefect": false
# 00105:     }
# 00106:   },
# 00107:   "Left": {
# 00108:     "IsSignaling": true
# 00109:   },
# 00110:   "Right": {
# 00111:     "IsDefect": true
# 00112:   },
# 00113:   "IsSignaling": true,
# 00114:   "Fog": {
# 00115:     "Front": {
# 00116:       "IsDefect": true
# 00117:     }
# 00118:   },
# 00119:   "Front": {
# 00120:     "IsOn": false
# 00121:   },
# 00122:   "Rear": {
# 00123:     "IsDefect": true
# 00124:   },
# 00125:   "Hazard": {
# 00126:     "IsDefect": false
# 00127:   },
# 00128:   "IsHighBeamSwitchOn": false,
# 00129:   "LicensePlate": "rfzeyeixwm",
# 00130:   "LightSwitch": "phgroqnmaf",
# 00131:   "Parking": {
# 00132:     "IsDefect": false
# 00133:   },
# 00134:   "Running": {
# 00135:     "IsDefect": false
# 00136:   },
# 00137:   "Mirrors": {
# 00138:     "DriverSide": {
# 00139:       "IsFolded": false
# 00140:     }
# 00141:   },
# 00142:   "DriverSide": {
# 00143:     "IsHeatingOn": true
# 00144:   },
# 00145:   "IsLocked": false,
# 00146:   "Pan": 98,
# 00147:   "Tilt": 54,
# 00148:   "PassengerSide": {
# 00149:     "IsFolded": true
# 00150:   },
# 00151:   "IsHeatingOn": false,
# 00152:   "Raindetection": {
# 00153:     "Intensity": 6
# 00154:   },
# 00155:   "RearMainSpoilerPosition": 68.64644739118776,
# 00156:   "RefuelPosition": "vdiuaocyuz",
# 00157:   "Trunk": {
# 00158:     "Front": {
# 00159:       "IsLightOn": false
# 00160:     }
# 00161:   },
# 00162:   "IsOpen": true,
# 00163:   "IsLightOn": false,
# 00164:   "Windshield": {
# 00165:     "Front": {
# 00166:       "IsHeatingOn": false
# 00167:     }
# 00168:   },
# 00169:   "WasherFluid": {
# 00170:     "IsLevelLow": false
# 00171:   },
# 00172:   "Level": "fbwcfqrexn",
# 00173:   "Wiping": {
# 00174:     "Intensity": 8
# 00175:   },
# 00176:   "IsWipersWorn": false,
# 00177:   "Mode": "EXTERNAL_ENTITY",
# 00178:   "System": {
# 00179:     "ActualPosition": 24.874616950333873
# 00180:   },
# 00181:   "DriveCurrent": 51.55348348304057,
# 00182:   "Frequency": 79,
# 00183:   "IsBlocked": true,
# 00184:   "IsEndingWipeCycle": true,
# 00185:   "IsOverheated": true,
# 00186:   "IsPositionReached": true,
# 00187:   "IsWiperError": true,
# 00188:   "IsWiping": false,
# 00189:   "TargetPosition": 41.72605156990456,
# 00190:   "WiperWear": 81,
# 00191:   "IsLevelLow": false,
# 00192:   "Intensity": 14,
# 00193:   "ActualPosition": 64.19815031449914,
# 00194:   "Cabin": {
# 00195:     "Convertible": {
# 00196:       "Status": "STALLED"
# 00197:     }
# 00198:   },
# 00199:   "Door": {
# 00200:     "Row1": {
# 00201:       "DriverSide": {
# 00202:         "IsChildLockActive": false
# 00203:       }
# 00204:     }
# 00205:   },
# 00206:   "Row1": {
# 00207:     "DriverSide": {
# 00208:       "IsLocked": false
# 00209:     }
# 00210:   },
# 00211:   "Shade": {
# 00212:     "IsOpen": false
# 00213:   },
# 00214:   "Window": {
# 00215:     "IsOpen": false
# 00216:   },
# 00217:   "IsChildLockActive": false,
# 00218:   "Row2": {
# 00219:     "DriverSide": {
# 00220:       "IsChildLockActive": false
# 00221:     }
# 00222:   },
# 00223:   "DoorCount": 64,
# 00224:   "DriverPosition": "RIGHT",
# 00225:   "HVAC": {
# 00226:     "AmbientAirTemperature": 82.8423892543812
# 00227:   },
# 00228:   "IsAirConditioningActive": false,
# 00229:   "IsFrontDefrosterActive": true,
# 00230:   "IsRearDefrosterActive": false,
# 00231:   "IsRecirculationActive": false,
# 00232:   "Station": {
# 00233:     "Row1": {
# 00234:       "Driver": {
# 00235:         "AirDistribution": "DOWN"
# 00236:       }
# 00237:     }
# 00238:   },
# 00239:   "Driver": {
# 00240:     "FanSpeed": 87
# 00241:   },
# 00242:   "Temperature": 59,
# 00243:   "Passenger": {
# 00244:     "AirDistribution": "eralqiqrny"
# 00245:   },
# 00246:   "FanSpeed": 17,
# 00247:   "AirDistribution": "UP",
# 00248:   "Row3": {
# 00249:     "Driver": {
# 00250:       "AirDistribution": "UP"
# 00251:     }
# 00252:   },
# 00253:   "Row4": {
# 00254:     "Driver": {
# 00255:       "AirDistribution": "DOWN"
# 00256:     }
# 00257:   },
# 00258:   "Infotainment": {
# 00259:     "HMI": {
# 00260:       "Brightness": 18.71143058159629
# 00261:     }
# 00262:   },
# 00263:   "HMI": {
# 00264:     "CurrentLanguage": "saeypmozoj"
# 00265:   },
# 00266:   "DateFormat": "YY_MM_DD",
# 00267:   "DayNightMode": "NIGHT",
# 00268:   "DisplayOffDuration": 41,
# 00269:   "DistanceUnit": "KILOMETERS",
# 00270:   "EVEconomyUnits": "MILES_PER_KILOWATT_HOUR",
# 00271:   "EVEnergyUnits": "AMPERE_HOURS",
# 00272:   "FontSize": "EXTRA_LARGE",
# 00273:   "FuelEconomyUnits": "MPG_UK",
# 00274:   "FuelVolumeUnit": "GALLON_US",
# 00275:   "IsScreenAlwaysOn": true,
# 00276:   "LastActionTime": "ecpgcevnsf",
# 00277:   "SpeedUnit": "METERS_PER_SECOND",
# 00278:   "TemperatureUnit": "C",
# 00279:   "TimeFormat": "HR_12",
# 00280:   "TirePressureUnit": "ksefvculsd",
# 00281:   "Media": {
# 00282:     "Action": "SKIP_BACKWARD"
# 00283:   },
# 00284:   "DeclinedURI": "cajiwcuzwu",
# 00285:   "Played": {
# 00286:     "Album": "segnykwvot"
# 00287:   },
# 00288:   "Artist": "mtjvczlwtu",
# 00289:   "PlaybackRate": 54.59127070032531,
# 00290:   "Source": "BLUETOOTH",
# 00291:   "Track": "cmjrydnwog",
# 00292:   "URI": "sbadudgpet",
# 00293:   "SelectedURI": "bcxfruater",
# 00294:   "Volume": 80,
# 00295:   "Navigation": {
# 00296:     "DestinationSet": {
# 00297:       "Latitude": 75.65281747710316
# 00298:     }
# 00299:   },
# 00300:   "DestinationSet": {
# 00301:     "Longitude": 21.38146389165625
# 00302:   },
# 00303:   "GuidanceVoice": "gengofkjms",
# 00304:   "Map": {
# 00305:     "IsAutoScaleModeUsed": false
# 00306:   },
# 00307:   "Mute": "UNMUTED",
# 00308:   "SmartphoneProjection": {
# 00309:     "Active": "NONE"
# 00310:   },
# 00311:   "SupportedMode": "wvoydatbwp",
# 00312:   "SmartphoneScreenMirroring": {
# 00313:     "Active": "INACTIVE"
# 00314:   },
# 00315:   "IsWindowChildLockEngaged": true,
# 00316:   "Light": {
# 00317:     "AmbientLight": {
# 00318:       "Row1": {
# 00319:         "DriverSide": {
# 00320:           "Color": "fzusnmlunz"
# 00321:         }
# 00322:       }
# 00323:     }
# 00324:   },
# 00325:   "AmbientLight": {
# 00326:     "Row1": {
# 00327:       "DriverSide": {
# 00328:         "Intensity": 45
# 00329:       }
# 00330:     }
# 00331:   },
# 00332:   "Color": "qwnqsvjqdg",
# 00333:   "InteractiveLightBar": {
# 00334:     "Color": "siiyioxrwk"
# 00335:   },
# 00336:   "Effect": "hppvicvbqe",
# 00337:   "IsDomeOn": true,
# 00338:   "IsGloveBoxOn": false,
# 00339:   "PerceivedAmbientLight": 8,
# 00340:   "Spotlight": {
# 00341:     "Row1": {
# 00342:       "DriverSide": {
# 00343:         "Color": "wvqlzxsyjw"
# 00344:       }
# 00345:     }
# 00346:   },
# 00347:   "RearShade": {
# 00348:     "IsOpen": false
# 00349:   },
# 00350:   "RearviewMirror": {
# 00351:     "DimmingLevel": 7
# 00352:   },
# 00353:   "Seat": {
# 00354:     "Row1": {
# 00355:       "DriverSide": {
# 00356:         "Airbag": {
# 00357:           "IsDeployed": true
# 00358:         }
# 00359:       }
# 00360:     }
# 00361:   },
# 00362:   "Backrest": {
# 00363:     "Lumbar": {
# 00364:       "Height": 97
# 00365:     }
# 00366:   },
# 00367:   "Lumbar": {
# 00368:     "Support": 41.58095317316144
# 00369:   },
# 00370:   "Recline": 80.18665559010121,
# 00371:   "SideBolster": {
# 00372:     "Support": 35.127393156300066
# 00373:   },
# 00374:   "Headrest": {
# 00375:     "Angle": 16.801299026728046
# 00376:   },
# 00377:   "Height": 24,
# 00378:   "Heating": 93,
# 00379:   "HeatingCooling": 56,
# 00380:   "IsBelted": false,
# 00381:   "IsOccupied": false,
# 00382:   "Massage": 88,
# 00383:   "Occupant": {
# 00384:     "Identifier": {
# 00385:       "Issuer": "kupazbqffp"
# 00386:     }
# 00387:   },
# 00388:   "Identifier": {
# 00389:     "Subject": "tmkvcxwccu"
# 00390:   },
# 00391:   "SeatBeltHeight": 83,
# 00392:   "Seating": {
# 00393:     "Length": 73
# 00394:   },
# 00395:   "IsReclineBackwardEngaged": true,
# 00396:   "IsReclineForwardEngaged": true,
# 00397:   "IsDownEngaged": true,
# 00398:   "IsLessSupportEngaged": false,
# 00399:   "IsMoreSupportEngaged": false,
# 00400:   "IsUpEngaged": false,
# 00401:   "IsBackwardEngaged": false,
# 00402:   "IsForwardEngaged": false,
# 00403:   "IsCoolerEngaged": true,
# 00404:   "IsTiltBackwardEngaged": true,
# 00405:   "IsTiltForwardEngaged": false,
# 00406:   "IsWarmerEngaged": false,
# 00407:   "IsDecreaseEngaged": false,
# 00408:   "IsIncreaseEngaged": false,
# 00409:   "Middle": {
# 00410:     "Airbag": {
# 00411:       "IsDeployed": true
# 00412:     }
# 00413:   },
# 00414:   "Support": 72.30164412590584,
# 00415:   "Angle": 12.083433708220303,
# 00416:   "Issuer": "fcrbfiinlr",
# 00417:   "Subject": "wzikbijlls",
# 00418:   "Length": 42,
# 00419:   "Airbag": {
# 00420:     "IsDeployed": false
# 00421:   },
# 00422:   "IsDeployed": false,
# 00423:   "SeatPosCount": [
# 00424:     88,
# 00425:     53,
# 00426:     34,
# 00427:     24,
# 00428:     43
# 00429:   ],
# 00430:   "SeatRowCount": 48,
# 00431:   "Sunroof": {
# 00432:     "Position": 75
# 00433:   },
# 00434:   "CargoVolume": 10.606243977487894,
# 00435:   "Chassis": {
# 00436:     "Accelerator": {
# 00437:       "PedalPosition": 72
# 00438:     }
# 00439:   },
# 00440:   "Axle": {
# 00441:     "Row1": {
# 00442:       "AxleWidth": 3
# 00443:     }
# 00444:   },
# 00445:   "SteeringAngle": 55.61897147138498,
# 00446:   "TireAspectRatio": 76,
# 00447:   "TireDiameter": 26.08972495218541,
# 00448:   "TireWidth": 8,
# 00449:   "TrackWidth": 19,
# 00450:   "TreadWidth": 26,
# 00451:   "Wheel": {
# 00452:     "Left": {
# 00453:       "AngularSpeed": 43.45230284699571
# 00454:     }
# 00455:   },
# 00456:   "FluidLevel": 60,
# 00457:   "IsBrakesWorn": false,
# 00458:   "IsFluidLevelLow": false,
# 00459:   "PadWear": 81,
# 00460:   "Speed": 11.464672472490001,
# 00461:   "Tire": {
# 00462:     "IsPressureLow": false
# 00463:   },
# 00464:   "Pressure": 68,
# 00465:   "AngularSpeed": 34.97000565634705,
# 00466:   "IsPressureLow": false,
# 00467:   "WheelCount": 17,
# 00468:   "WheelDiameter": 0.3728936017711737,
# 00469:   "WheelWidth": 50.27615596616863,
# 00470:   "AxleWidth": 62,
# 00471:   "AxleCount": 82,
# 00472:   "IsDriverEmergencyBrakingDetected": true,
# 00473:   "PedalPosition": 35,
# 00474:   "ParkingBrake": {
# 00475:     "IsAutoApplyEnabled": true
# 00476:   },
# 00477:   "SteeringWheel": {
# 00478:     "Angle": -75
# 00479:   },
# 00480:   "Extension": 5,
# 00481:   "Wheelbase": 80,
# 00482:   "Connectivity": {
# 00483:     "IsConnectivityAvailable": true
# 00484:   },
# 00485:   "CurbWeight": 20,
# 00486:   "CurrentLocation": {
# 00487:     "Altitude": 8.361711495783354
# 00488:   },
# 00489:   "GNSSReceiver": {
# 00490:     "FixType": "THREE_D_SATELLITE_BASED_AUGMENTATION"
# 00491:   },
# 00492:   "MountingPosition": {
# 00493:     "X": 43
# 00494:   },
# 00495:   "Y": -72,
# 00496:   "Z": 25,
# 00497:   "Heading": 2.9103933189051134,
# 00498:   "HorizontalAccuracy": 74.98210036058069,
# 00499:   "Latitude": 58.37643926092988,
# 00500:   "Longitude": 10.206856597888347,
# 00501:   "Timestamp": "twladakjtj",
# 00502:   "VerticalAccuracy": 96.43264163896376,
# 00503:   "CurrentOverallWeight": 31,
# 00504:   "Diagnostics": {
# 00505:     "DTCCount": 38
# 00506:   },
# 00507:   "DTCList": [
# 00508:     "gcilajzspp",
# 00509:     "mflohyzihr",
# 00510:     "uoqmeypqos",
# 00511:     "xmthjlopvv"
# 00512:   ],
# 00513:   "AttentiveProbability": 25.49283483195417,
# 00514:   "DistractionLevel": 62.43498937711276,
# 00515:   "FatigueLevel": 8.389403003911966,
# 00516:   "HeartRate": 12,
# 00517:   "IsEyesOnRoad": true,
# 00518:   "IsHandsOnWheel": true,
# 00519:   "EmissionsCO2": 61,
# 00520:   "Exterior": {
# 00521:     "AirTemperature": 16.759975677345253
# 00522:   },
# 00523:   "Humidity": 41.65818991346741,
# 00524:   "LightIntensity": 83.3519412808265,
# 00525:   "GrossWeight": 62,
# 00526:   "IsBrokenDown": false,
# 00527:   "IsMoving": false,
# 00528:   "LowVoltageBattery": {
# 00529:     "CurrentCurrent": 75.00682918979147
# 00530:   },
# 00531:   "CurrentVoltage": 68.65390442268648,
# 00532:   "NominalCapacity": 74,
# 00533:   "NominalVoltage": 12,
# 00534:   "LowVoltageSystemState": "ON",
# 00535:   "MaxTowBallWeight": 93,
# 00536:   "MaxTowWeight": 60,
# 00537:   "OBD": {
# 00538:     "AbsoluteLoad": 80.42737852532322
# 00539:   },
# 00540:   "AcceleratorPositionD": 80.40270257701063,
# 00541:   "AcceleratorPositionE": 51.93821579314225,
# 00542:   "AcceleratorPositionF": 45.42419444908234,
# 00543:   "AirStatus": "rhhiduzhke",
# 00544:   "AmbientAirTemperature": 1.1803165601933285,
# 00545:   "BarometricPressure": 90.46237685675112,
# 00546:   "Catalyst": {
# 00547:     "Bank1": {
# 00548:       "Temperature1": 10.255599355885392
# 00549:     }
# 00550:   },
# 00551:   "Bank1": {
# 00552:     "Temperature2": 14.436700415862125
# 00553:   },
# 00554:   "Bank2": {
# 00555:     "Temperature1": 99.59365626176549
# 00556:   },
# 00557:   "Temperature2": 55.468220056237136,
# 00558:   "CommandedEGR": 30.132106799450685,
# 00559:   "CommandedEVAP": 83.6401472567999,
# 00560:   "CommandedEquivalenceRatio": 94.82438183537882,
# 00561:   "ControlModuleVoltage": 68.70092140384853,
# 00562:   "CoolantTemperature": 71.96877781603862,
# 00563:   "DistanceSinceDTCClear": 11.694808812785363,
# 00564:   "DistanceWithMIL": 56.78351511254035,
# 00565:   "DriveCycleStatus": {
# 00566:     "DTCCount": 63
# 00567:   },
# 00568:   "IgnitionType": "SPARK",
# 00569:   "IsMILOn": false,
# 00570:   "EGRError": 67.85796530834189,
# 00571:   "EVAPVaporPressure": 10.695701328387585,
# 00572:   "EVAPVaporPressureAbsolute": 70.58357279919257,
# 00573:   "EVAPVaporPressureAlternate": 37.391440712715976,
# 00574:   "EngineLoad": 70.79760543972827,
# 00575:   "EngineSpeed": 32.69852312594139,
# 00576:   "EthanolPercent": 68.0601324118383,
# 00577:   "FreezeDTC": "kkhqwqfrwc",
# 00578:   "FuelInjectionTiming": 66.29234680245557,
# 00579:   "FuelLevel": 19.22954180710623,
# 00580:   "FuelPressure": 31.797543522158435,
# 00581:   "FuelRailPressureAbsolute": 22.083573204062002,
# 00582:   "FuelRailPressureDirect": 96.92376587595662,
# 00583:   "FuelRailPressureVac": 75.7966383737042,
# 00584:   "FuelRate": 67.36836259669857,
# 00585:   "FuelStatus": "rwoxvxcyqn",
# 00586:   "FuelType": 89,
# 00587:   "HybridBatteryRemaining": 36.43422163285881,
# 00588:   "IntakeTemp": 3.272694828730338,
# 00589:   "IsPTOActive": true,
# 00590:   "LongTermFuelTrim1": 92.95690423623346,
# 00591:   "LongTermFuelTrim2": 61.11544998467045,
# 00592:   "LongTermO2Trim1": 50.84658686022775,
# 00593:   "LongTermO2Trim2": 66.0456980818315,
# 00594:   "LongTermO2Trim3": 12.946100890486656,
# 00595:   "LongTermO2Trim4": 58.52431823087374,
# 00596:   "MAF": 27,
# 00597:   "MAP": 9,
# 00598:   "MaxMAF": 98.70464610198744,
# 00599:   "O2": {
# 00600:     "Sensor1": {
# 00601:       "ShortTermFuelTrim": 77.39115960298552
# 00602:     }
# 00603:   },
# 00604:   "Sensor1": {
# 00605:     "Voltage": 23.098957450964786
# 00606:   },
# 00607:   "Sensor2": {
# 00608:     "ShortTermFuelTrim": 64.57452707747348
# 00609:   },
# 00610:   "Voltage": 12.30944548531534,
# 00611:   "Sensor3": {
# 00612:     "ShortTermFuelTrim": 45.882791352128294
# 00613:   },
# 00614:   "Sensor4": {
# 00615:     "ShortTermFuelTrim": 16.092786703514516
# 00616:   },
# 00617:   "Sensor5": {
# 00618:     "ShortTermFuelTrim": 92.34360346511788
# 00619:   },
# 00620:   "Sensor6": {
# 00621:     "ShortTermFuelTrim": 98.8182384018834
# 00622:   },
# 00623:   "Sensor7": {
# 00624:     "ShortTermFuelTrim": 73.26570681248478
# 00625:   },
# 00626:   "Sensor8": {
# 00627:     "ShortTermFuelTrim": 45.32076989523258
# 00628:   },
# 00629:   "O2WR": {
# 00630:     "Sensor1": {
# 00631:       "Current": 74.27587030390978
# 00632:     }
# 00633:   },
# 00634:   "Lambda": 32.485045484312344,
# 00635:   "Current": 62.986327174168736,
# 00636:   "OBDStandards": 7,
# 00637:   "OilTemperature": 91.67491324632368,
# 00638:   "OxygenSensorsIn2Banks": 53,
# 00639:   "OxygenSensorsIn4Banks": 3,
# 00640:   "PidsA": "fdlttdqnin",
# 00641:   "PidsB": "24",
# 00642:   "PidsC": "5B",
# 00643:   "RelativeAcceleratorPosition": 22.974781472366956,
# 00644:   "RelativeThrottlePosition": 12.193586648130095,
# 00645:   "RunTime": 88.13945373699242,
# 00646:   "RunTimeMIL": 8.077874557309483,
# 00647:   "ShortTermFuelTrim1": 73.84648894619514,
# 00648:   "ShortTermFuelTrim2": 18.150972569632316,
# 00649:   "ShortTermO2Trim1": 14.235645428061295,
# 00650:   "ShortTermO2Trim2": 40.80778210487265,
# 00651:   "ShortTermO2Trim3": 4.777152065034851,
# 00652:   "ShortTermO2Trim4": 70.54706049101769,
# 00653:   "Status": {
# 00654:     "DTCCount": 94
# 00655:   },
# 00656:   "ThrottleActuator": 21.70114886198381,
# 00657:   "ThrottlePosition": 15.041257768946947,
# 00658:   "ThrottlePositionB": 56.830190684405416,
# 00659:   "ThrottlePositionC": 63.6492522983607,
# 00660:   "TimeSinceDTCCleared": 32.20250267846877,
# 00661:   "TimingAdvance": 2.689091153213574,
# 00662:   "WarmupsSinceDTCClear": 85,
# 00663:   "HeadPosition": {
# 00664:     "Pitch": 7.036603099907934
# 00665:   },
# 00666:   "X": -17,
# 00667:   "MidEyeGaze": {
# 00668:     "Azimuth": 35.10415035019191
# 00669:   },
# 00670:   "Elevation": 99.46715326067614,
# 00671:   "Pitch": 97.06231512519572,
# 00672:   "Azimuth": 84.43219978333512,
# 00673:   "Powertrain": {
# 00674:     "AccumulatedBrakingEnergy": 90.59469984457142
# 00675:   },
# 00676:   "CombustionEngine": {
# 00677:     "AspirationType": "UNKNOWN"
# 00678:   },
# 00679:   "Bore": 81.33038500152998,
# 00680:   "CompressionRatio": "qutoslvbvv",
# 00681:   "Configuration": "bgovxvghuk",
# 00682:   "DieselExhaustFluid": {
# 00683:     "Capacity": 17.47422654162588
# 00684:   },
# 00685:   "Range": 55,
# 00686:   "DieselParticulateFilter": {
# 00687:     "DeltaPressure": 8.725874188647465
# 00688:   },
# 00689:   "InletTemperature": 12.47279288653953,
# 00690:   "OutletTemperature": 32.883742721673435,
# 00691:   "Displacement": 20,
# 00692:   "ECT": 36,
# 00693:   "EOP": 65,
# 00694:   "EOT": -33,
# 00695:   "EngineCode": "qcodabqiko",
# 00696:   "EngineCoolant": {
# 00697:     "Capacity": 36.19552125448146
# 00698:   },
# 00699:   "LifeRemaining": -41,
# 00700:   "EngineCoolantCapacity": 47.26020203968362,
# 00701:   "EngineHours": 48.22090237770056,
# 00702:   "EngineOil": {
# 00703:     "Capacity": 75.32878919097779
# 00704:   },
# 00705:   "EngineOilCapacity": 93.42886293050171,
# 00706:   "EngineOilLevel": "LOW",
# 00707:   "IdleHours": 66.89386502573433,
# 00708:   "IsRunning": false,
# 00709:   "MaxPower": 57.33723753687341,
# 00710:   "MaxTorque": 11,
# 00711:   "NumberOfCylinders": 46,
# 00712:   "NumberOfValvesPerCylinder": 66,
# 00713:   "OilLifeRemaining": 49,
# 00714:   "Power": 85,
# 00715:   "StrokeLength": 47.026631911588936,
# 00716:   "TPS": 20,
# 00717:   "Torque": 77,
# 00718:   "ElectricMotor": {
# 00719:     "CoolantTemperature": 100
# 00720:   },
# 00721:   "Capacity": 97.37716045430767,
# 00722:   "MaxRegenPower": 15,
# 00723:   "MaxRegenTorque": 28,
# 00724:   "TimeInUse": 8.12628011462695,
# 00725:   "FuelSystem": {
# 00726:     "AbsoluteLevel": 19.84434796116894
# 00727:   },
# 00728:   "AverageConsumption": 74.91014368856966,
# 00729:   "ConsumptionSinceStart": 93.56572267766474,
# 00730:   "HybridType": "CIMG",
# 00731:   "InstantConsumption": 73.24348189854192,
# 00732:   "IsEngineStopStartEnabled": false,
# 00733:   "IsFuelLevelLow": false,
# 00734:   "IsFuelPortFlapOpen": false,
# 00735:   "RefuelPortPosition": "FRONT_LEFT",
# 00736:   "RelativeLevel": 24,
# 00737:   "SupportedFuel": "pzrzlzftme",
# 00738:   "SupportedFuelTypes": "pookwgcxjz",
# 00739:   "TankCapacity": 90.76347168659429,
# 00740:   "TimeRemaining": 37,
# 00741:   "TractionBattery": {
# 00742:     "AccumulatedChargedEnergy": 0.0967393241068426
# 00743:   },
# 00744:   "AccumulatedChargedThroughput": 99.77394298557243,
# 00745:   "AccumulatedConsumedEnergy": 52.77517789388085,
# 00746:   "AccumulatedConsumedThroughput": 9.228118344210035,
# 00747:   "BatteryConditioning": {
# 00748:     "IsActive": false
# 00749:   },
# 00750:   "IsOngoing": false,
# 00751:   "RequestedMode": "DRIVING_PREPARATION",
# 00752:   "StartTime": "ivvlfxsxpe",
# 00753:   "TargetTemperature": 88.14995090875227,
# 00754:   "TargetTime": "ssiwdqawnl",
# 00755:   "CellVoltage": {
# 00756:     "CellVoltages": [
# 00757:       2.1653647865574333,
# 00758:       33.754007941010386,
# 00759:       41.21457838319723,
# 00760:       30.532539793715095,
# 00761:       69.5738006491624
# 00762:     ]
# 00763:   },
# 00764:   "CellVoltages": [
# 00765:     2.1653647865574333,
# 00766:     33.754007941010386,
# 00767:     41.21457838319723,
# 00768:     30.532539793715095,
# 00769:     69.5738006491624
# 00770:   ],
# 00771:   "IdMax": 20,
# 00772:   "IdMin": 20,
# 00773:   "Max": 6.576400786082015,
# 00774:   "Min": 66.75661731599617,
# 00775:   "Charging": {
# 00776:     "AveragePower": 34.217490571260434
# 00777:   },
# 00778:   "ChargeCurrent": {
# 00779:     "DC": 98.62666559054604
# 00780:   },
# 00781:   "Phase1": 68.38664697717587,
# 00782:   "Phase2": 87.86021828316589,
# 00783:   "Phase3": 86.78419580306957,
# 00784:   "ChargeLimit": 68,
# 00785:   "ChargePlugType": "IEC_TYPE_4_DC",
# 00786:   "ChargePortFlap": "OPEN",
# 00787:   "ChargePortPosition": "LEFT_REAR",
# 00788:   "ChargePortType": "fnsyuzvvht",
# 00789:   "ChargeRate": 97.78445473370496,
# 00790:   "ChargeVoltage": {
# 00791:     "DC": 93.44965032665063
# 00792:   },
# 00793:   "EvseId": "zkomkaitkz",
# 00794:   "IsChargePortFlapOpen": true,
# 00795:   "IsCharging": false,
# 00796:   "IsChargingCableConnected": true,
# 00797:   "IsChargingCableLocked": false,
# 00798:   "IsDischarging": false,
# 00799:   "Location": {
# 00800:     "Altitude": 59.26618495705254
# 00801:   },
# 00802:   "MaximumChargingCurrent": {
# 00803:     "DC": 75.76702317113792
# 00804:   },
# 00805:   "PowerLoss": 51.24763891517031,
# 00806:   "StartStopCharging": "STOP",
# 00807:   "TimeToComplete": 39,
# 00808:   "Timer": {
# 00809:     "Mode": "START_TIME"
# 00810:   },
# 00811:   "Time": "dlzmnmeyqy",
# 00812:   "CurrentCurrent": 23.07322155830799,
# 00813:   "CurrentPower": 98.67099916660807,
# 00814:   "DCDC": {
# 00815:     "PowerLoss": 75.64452870276035
# 00816:   },
# 00817:   "ErrorCodes": [
# 00818:     "pfczieygsh",
# 00819:     "hfxyvhidcq"
# 00820:   ],
# 00821:   "GrossCapacity": 71,
# 00822:   "Id": "mexwngnjfa",
# 00823:   "IsGroundConnected": false,
# 00824:   "IsPowerConnected": true,
# 00825:   "MaxVoltage": 85,
# 00826:   "NetCapacity": 30,
# 00827:   "ProductionDate": "ifccquxdrr",
# 00828:   "StateOfCharge": {
# 00829:     "Current": 93.9962310313489
# 00830:   },
# 00831:   "CurrentEnergy": 87.15677317836307,
# 00832:   "Displayed": 81.98796712069336,
# 00833:   "StateOfHealth": 9.649840768015217,
# 00834:   "Average": 85.72201024390506,
# 00835:   "CellTemperature": [
# 00836:     33.01014699788571,
# 00837:     14.470358323872311,
# 00838:     62.53688414781169,
# 00839:     82.25135037383093
# 00840:   ],
# 00841:   "Transmission": {
# 00842:     "ClutchEngagement": 75.31857526876951
# 00843:   },
# 00844:   "ClutchWear": 9,
# 00845:   "CurrentGear": 97,
# 00846:   "DiffLockFrontEngagement": 33.37183261965504,
# 00847:   "DiffLockRearEngagement": 36.076801816246885,
# 00848:   "DriveType": "ALL_WHEEL_DRIVE",
# 00849:   "GearChangeMode": "AUTOMATIC",
# 00850:   "GearCount": 43,
# 00851:   "IsElectricalPowertrainEngaged": false,
# 00852:   "IsLowRangeEngaged": false,
# 00853:   "IsParkLockEngaged": true,
# 00854:   "PerformanceMode": "NORMAL",
# 00855:   "SelectedGear": 79,
# 00856:   "TorqueDistribution": 80.13175342285135,
# 00857:   "TravelledDistance": 9.584313316591142,
# 00858:   "Type": "ELECTRIC",
# 00859:   "RoofLoad": 35,
# 00860:   "Service": {
# 00861:     "DistanceToService": 73.99341010985675
# 00862:   },
# 00863:   "IsServiceDue": false,
# 00864:   "TimeToService": 31,
# 00865:   "Trailer": {
# 00866:     "IsConnected": false
# 00867:   },
# 00868:   "TraveledDistance": 96.29542721822662,
# 00869:   "TraveledDistanceSinceStart": 78.93365777432213,
# 00870:   "TripDuration": 51.131712173740965,
# 00871:   "TripMeterReading": 35.01806503068507,
# 00872:   "TurningDiameter": 74,
# 00873:   "VehicleIdentification": {
# 00874:     "AcrissCode": "gdwldzzaxw"
# 00875:   },
# 00876:   "BodyType": "lpzcprzwtr",
# 00877:   "Brand": "tnaculdzgz",
# 00878:   "DateVehicleFirstRegistered": "uxtojugcku",
# 00879:   "KnownVehicleDamages": "ymzzjszrrq",
# 00880:   "MeetsEmissionStandard": "emfjgfeyst",
# 00881:   "Model": "gudhouvsya",
# 00882:   "OptionalExtras": [
# 00883:     "blmmqfhhtl",
# 00884:     "extooqfzdg",
# 00885:     "qiqwmmwzvu"
# 00886:   ],
# 00887:   "PurchaseDate": "peajaysffc",
# 00888:   "VIN": "nessjpckog",
# 00889:   "VehicleConfiguration": "vnrbpgvjzx",
# 00890:   "VehicleExteriorColor": "pxlzeovcjk",
# 00891:   "VehicleInteriorColor": "whxjefvxpl",
# 00892:   "VehicleInteriorType": "ntknmbqxba",
# 00893:   "VehicleModelDate": "wvoungamcc",
# 00894:   "VehicleSeatingCapacity": 10,
# 00895:   "VehicleSpecialUsage": "cgpfceamrb",
# 00896:   "WMI": "hzwygekrnb",
# 00897:   "Year": 72,
# 00898:   "VersionVSS": {
# 00899:     "Label": "rhpidntiog"
# 00900:   },
# 00901:   "Major": 1,
# 00902:   "Minor": 76,
# 00903:   "Patch": 83,
# 00904:   "Width": 11,
# 00905:   "WidthExcludingMirrors": 93,
# 00906:   "WidthFoldedMirrors": 10,
# 00907:   "WidthIncludingMirrors": 23
# 00908: }

# %%
patch.print(2, True)
# Out:
# 00001: [
# 00002:   {
# 00003:     "op": "add",
# 00004:     "path": "/CellVoltages",
# 00005:     "value": [
# 00006:       2.1653647865574333,
# 00007:       33.754007941010386,
# 00008:       41.21457838319723,
# 00009:       30.532539793715095,
# 00010:       69.5738006491624
# 00011:     ]
# 00012:   },
# 00013:   {
# 00014:     "op": "replace",
# 00015:     "path": "/FuelSystem/AbsoluteLevel",
# 00016:     "value": 19.84434796116894
# 00017:   },
# 00018:   {
# 00019:     "op": "replace",
# 00020:     "path": "/Brand",
# 00021:     "value": "tnaculdzgz"
# 00022:   },
# 00023:   {
# 00024:     "op": "replace",
# 00025:     "path": "/TimeInUse",
# 00026:     "value": 8.12628011462695
# 00027:   },
# 00028:   {
# 00029:     "op": "replace",
# 00030:     "path": "/ChargeVoltage/DC",
# 00031:     "value": 93.44965032665063
# 00032:   },
# 00033:   {
# 00034:     "op": "replace",
# 00035:     "path": "/NumberOfValvesPerCylinder",
# 00036:     "value": 66
# 00037:   },
# 00038:   {
# 00039:     "op": "replace",
# 00040:     "path": "/Infotainment/HMI/Brightness",
# 00041:     "value": 18.71143058159629
# 00042:   },
# 00043:   {
# 00044:     "op": "replace",
# 00045:     "path": "/Wheelbase",
# 00046:     "value": 80
# 00047:   },
# 00048:   {
# 00049:     "op": "replace",
# 00050:     "path": "/IsUpEngaged",
# 00051:     "value": false
# 00052:   },
# 00053:   {
# 00054:     "op": "replace",
# 00055:     "path": "/Backup/IsOn",
# 00056:     "value": false
# 00057:   },
# 00058:   {
# 00059:     "op": "replace",
# 00060:     "path": "/Level",
# 00061:     "value": "fbwcfqrexn"
# 00062:   },
# 00063:   {
# 00064:     "op": "replace",
# 00065:     "path": "/IsOngoing",
# 00066:     "value": false
# 00067:   },
# 00068:   {
# 00069:     "op": "replace",
# 00070:     "path": "/VehicleSeatingCapacity",
# 00071:     "value": 10
# 00072:   },
# 00073:   {
# 00074:     "op": "replace",
# 00075:     "path": "/OilTemperature",
# 00076:     "value": 91.67491324632368
# 00077:   },
# 00078:   {
# 00079:     "op": "replace",
# 00080:     "path": "/Played/Album",
# 00081:     "value": "segnykwvot"
# 00082:   },
# 00083:   {
# 00084:     "op": "replace",
# 00085:     "path": "/Latitude",
# 00086:     "value": 58.37643926092988
# 00087:   },
# 00088:   {
# 00089:     "op": "replace",
# 00090:     "path": "/RoadFriction/LowerBound",
# 00091:     "value": 34.68654028185373
# 00092:   },
# 00093:   {
# 00094:     "op": "replace",
# 00095:     "path": "/FuelType",
# 00096:     "value": 89
# 00097:   },
# 00098:   {
# 00099:     "op": "replace",
# 00100:     "path": "/EngineCoolantCapacity",
# 00101:     "value": 47.26020203968362
# 00102:   },
# 00103:   {
# 00104:     "op": "replace",
# 00105:     "path": "/IsAirConditioningActive",
# 00106:     "value": false
# 00107:   },
# 00108:   {
# 00109:     "op": "replace",
# 00110:     "path": "/Capacity",
# 00111:     "value": 97.37716045430767
# 00112:   },
# 00113:   {
# 00114:     "op": "replace",
# 00115:     "path": "/RearShade/IsOpen",
# 00116:     "value": false
# 00117:   },
# 00118:   {
# 00119:     "op": "replace",
# 00120:     "path": "/RunTime",
# 00121:     "value": 88.13945373699242
# 00122:   },
# 00123:   {
# 00124:     "op": "replace",
# 00125:     "path": "/Right/IsDefect",
# 00126:     "value": true
# 00127:   },
# 00128:   {
# 00129:     "op": "replace",
# 00130:     "path": "/Configuration",
# 00131:     "value": "bgovxvghuk"
# 00132:   },
# 00133:   {
# 00134:     "op": "replace",
# 00135:     "path": "/Passenger/AirDistribution",
# 00136:     "value": "eralqiqrny"
# 00137:   },
# 00138:   {
# 00139:     "op": "replace",
# 00140:     "path": "/MaxRegenTorque",
# 00141:     "value": 28
# 00142:   },
# 00143:   {
# 00144:     "op": "replace",
# 00145:     "path": "/CargoVolume",
# 00146:     "value": 10.606243977487894
# 00147:   },
# 00148:   {
# 00149:     "op": "replace",
# 00150:     "path": "/IsPowerConnected",
# 00151:     "value": true
# 00152:   },
# 00153:   {
# 00154:     "op": "replace",
# 00155:     "path": "/AmbientAirTemperature",
# 00156:     "value": 1.1803165601933285
# 00157:   },
# 00158:   {
# 00159:     "op": "replace",
# 00160:     "path": "/IsTiltBackwardEngaged",
# 00161:     "value": true
# 00162:   },
# 00163:   {
# 00164:     "op": "replace",
# 00165:     "path": "/Longitudinal",
# 00166:     "value": 80.38981574991556
# 00167:   },
# 00168:   {
# 00169:     "op": "replace",
# 00170:     "path": "/OilLifeRemaining",
# 00171:     "value": 49
# 00172:   },
# 00173:   {
# 00174:     "op": "replace",
# 00175:     "path": "/IsPTOActive",
# 00176:     "value": true
# 00177:   },
# 00178:   {
# 00179:     "op": "replace",
# 00180:     "path": "/TractionBattery/AccumulatedChargedEnergy",
# 00181:     "value": 0.0967393241068426
# 00182:   },
# 00183:   {
# 00184:     "op": "replace",
# 00185:     "path": "/Subject",
# 00186:     "value": "wzikbijlls"
# 00187:   },
# 00188:   {
# 00189:     "op": "replace",
# 00190:     "path": "/VehicleSpecialUsage",
# 00191:     "value": "cgpfceamrb"
# 00192:   },
# 00193:   {
# 00194:     "op": "replace",
# 00195:     "path": "/MaxTowWeight",
# 00196:     "value": 60
# 00197:   },
# 00198:   {
# 00199:     "op": "replace",
# 00200:     "path": "/FuelStatus",
# 00201:     "value": "rwoxvxcyqn"
# 00202:   },
# 00203:   {
# 00204:     "op": "replace",
# 00205:     "path": "/GuidanceVoice",
# 00206:     "value": "gengofkjms"
# 00207:   },
# 00208:   {
# 00209:     "op": "replace",
# 00210:     "path": "/TankCapacity",
# 00211:     "value": 90.76347168659429
# 00212:   },
# 00213:   {
# 00214:     "op": "replace",
# 00215:     "path": "/Phase3",
# 00216:     "value": 86.78419580306957
# 00217:   },
# 00218:   {
# 00219:     "op": "replace",
# 00220:     "path": "/TirePressureUnit",
# 00221:     "value": "ksefvculsd"
# 00222:   },
# 00223:   {
# 00224:     "op": "replace",
# 00225:     "path": "/MountingPosition/X",
# 00226:     "value": 43
# 00227:   },
# 00228:   {
# 00229:     "op": "replace",
# 00230:     "path": "/IsCharging",
# 00231:     "value": false
# 00232:   },
# 00233:   {
# 00234:     "op": "replace",
# 00235:     "path": "/CruiseControl/IsActive",
# 00236:     "value": true
# 00237:   },
# 00238:   {
# 00239:     "op": "replace",
# 00240:     "path": "/CommandedEquivalenceRatio",
# 00241:     "value": 94.82438183537882
# 00242:   },
# 00243:   {
# 00244:     "op": "replace",
# 00245:     "path": "/O2/Sensor1/ShortTermFuelTrim",
# 00246:     "value": 77.39115960298552
# 00247:   },
# 00248:   {
# 00249:     "op": "replace",
# 00250:     "path": "/TimeSinceDTCCleared",
# 00251:     "value": 32.20250267846877
# 00252:   },
# 00253:   {
# 00254:     "op": "replace",
# 00255:     "path": "/SupportedFuel",
# 00256:     "value": "pzrzlzftme"
# 00257:   },
# 00258:   {
# 00259:     "op": "replace",
# 00260:     "path": "/LaneDepartureDetection/IsEnabled",
# 00261:     "value": false
# 00262:   },
# 00263:   {
# 00264:     "op": "replace",
# 00265:     "path": "/IsEndingWipeCycle",
# 00266:     "value": true
# 00267:   },
# 00268:   {
# 00269:     "op": "replace",
# 00270:     "path": "/IsMoreSupportEngaged",
# 00271:     "value": false
# 00272:   },
# 00273:   {
# 00274:     "op": "replace",
# 00275:     "path": "/SupportedFuelTypes",
# 00276:     "value": "pookwgcxjz"
# 00277:   },
# 00278:   {
# 00279:     "op": "replace",
# 00280:     "path": "/IsFuelLevelLow",
# 00281:     "value": false
# 00282:   },
# 00283:   {
# 00284:     "op": "replace",
# 00285:     "path": "/SupportedMode",
# 00286:     "value": "wvoydatbwp"
# 00287:   },
# 00288:   {
# 00289:     "op": "replace",
# 00290:     "path": "/TreadWidth",
# 00291:     "value": 26
# 00292:   },
# 00293:   {
# 00294:     "op": "replace",
# 00295:     "path": "/DoorCount",
# 00296:     "value": 64
# 00297:   },
# 00298:   {
# 00299:     "op": "replace",
# 00300:     "path": "/LicensePlate",
# 00301:     "value": "rfzeyeixwm"
# 00302:   },
# 00303:   {
# 00304:     "op": "replace",
# 00305:     "path": "/MaxTorque",
# 00306:     "value": 11
# 00307:   },
# 00308:   {
# 00309:     "op": "replace",
# 00310:     "path": "/Lambda",
# 00311:     "value": 32.485045484312344
# 00312:   },
# 00313:   {
# 00314:     "op": "replace",
# 00315:     "path": "/Model",
# 00316:     "value": "gudhouvsya"
# 00317:   },
# 00318:   {
# 00319:     "op": "replace",
# 00320:     "path": "/Azimuth",
# 00321:     "value": 84.43219978333512
# 00322:   },
# 00323:   {
# 00324:     "op": "replace",
# 00325:     "path": "/AverageSpeed",
# 00326:     "value": 13.50799931551563
# 00327:   },
# 00328:   {
# 00329:     "op": "replace",
# 00330:     "path": "/PowerOptimizeLevel",
# 00331:     "value": 63
# 00332:   },
# 00333:   {
# 00334:     "op": "replace",
# 00335:     "path": "/TireWidth",
# 00336:     "value": 8
# 00337:   },
# 00338:   {
# 00339:     "op": "replace",
# 00340:     "path": "/AmbientLight/Row1/DriverSide/Intensity",
# 00341:     "value": 45
# 00342:   },
# 00343:   {
# 00344:     "op": "replace",
# 00345:     "path": "/LightSwitch",
# 00346:     "value": "phgroqnmaf"
# 00347:   },
# 00348:   {
# 00349:     "op": "replace",
# 00350:     "path": "/AirStatus",
# 00351:     "value": "rhhiduzhke"
# 00352:   },
# 00353:   {
# 00354:     "op": "replace",
# 00355:     "path": "/CommandedEGR",
# 00356:     "value": 30.132106799450685
# 00357:   },
# 00358:   {
# 00359:     "op": "replace",
# 00360:     "path": "/IsHighBeamSwitchOn",
# 00361:     "value": false
# 00362:   },
# 00363:   {
# 00364:     "op": "replace",
# 00365:     "path": "/IntakeTemp",
# 00366:     "value": 3.272694828730338
# 00367:   },
# 00368:   {
# 00369:     "op": "replace",
# 00370:     "path": "/CurrentPower",
# 00371:     "value": 98.67099916660807
# 00372:   },
# 00373:   {
# 00374:     "op": "replace",
# 00375:     "path": "/BodyType",
# 00376:     "value": "lpzcprzwtr"
# 00377:   },
# 00378:   {
# 00379:     "op": "replace",
# 00380:     "path": "/MAP",
# 00381:     "value": 9
# 00382:   },
# 00383:   {
# 00384:     "op": "replace",
# 00385:     "path": "/ESC/IsEnabled",
# 00386:     "value": true
# 00387:   },
# 00388:   {
# 00389:     "op": "replace",
# 00390:     "path": "/IsReclineBackwardEngaged",
# 00391:     "value": true
# 00392:   },
# 00393:   {
# 00394:     "op": "replace",
# 00395:     "path": "/TargetTime",
# 00396:     "value": "ssiwdqawnl"
# 00397:   },
# 00398:   {
# 00399:     "op": "replace",
# 00400:     "path": "/IdMin",
# 00401:     "value": 20
# 00402:   },
# 00403:   {
# 00404:     "op": "replace",
# 00405:     "path": "/RoofLoad",
# 00406:     "value": 35
# 00407:   },
# 00408:   {
# 00409:     "op": "replace",
# 00410:     "path": "/LongTermO2Trim4",
# 00411:     "value": 58.52431823087374
# 00412:   },
# 00413:   {
# 00414:     "op": "replace",
# 00415:     "path": "/Sensor6/ShortTermFuelTrim",
# 00416:     "value": 98.8182384018834
# 00417:   },
# 00418:   {
# 00419:     "op": "replace",
# 00420:     "path": "/Left/IsSignaling",
# 00421:     "value": true
# 00422:   },
# 00423:   {
# 00424:     "op": "replace",
# 00425:     "path": "/PlaybackRate",
# 00426:     "value": 54.59127070032531
# 00427:   },
# 00428:   {
# 00429:     "op": "replace",
# 00430:     "path": "/Window/IsOpen",
# 00431:     "value": false
# 00432:   },
# 00433:   {
# 00434:     "op": "replace",
# 00435:     "path": "/Effect",
# 00436:     "value": "hppvicvbqe"
# 00437:   },
# 00438:   {
# 00439:     "op": "replace",
# 00440:     "path": "/TargetPosition",
# 00441:     "value": 41.72605156990456
# 00442:   },
# 00443:   {
# 00444:     "op": "replace",
# 00445:     "path": "/ChargePortType",
# 00446:     "value": "fnsyuzvvht"
# 00447:   },
# 00448:   {
# 00449:     "op": "replace",
# 00450:     "path": "/Heading",
# 00451:     "value": 2.9103933189051134
# 00452:   },
# 00453:   {
# 00454:     "op": "replace",
# 00455:     "path": "/IsEnabled",
# 00456:     "value": true
# 00457:   },
# 00458:   {
# 00459:     "op": "replace",
# 00460:     "path": "/IsMILOn",
# 00461:     "value": false
# 00462:   },
# 00463:   {
# 00464:     "op": "replace",
# 00465:     "path": "/IsDefect",
# 00466:     "value": true
# 00467:   },
# 00468:   {
# 00469:     "op": "replace",
# 00470:     "path": "/WarmupsSinceDTCClear",
# 00471:     "value": 85
# 00472:   },
# 00473:   {
# 00474:     "op": "replace",
# 00475:     "path": "/RefuelPosition",
# 00476:     "value": "vdiuaocyuz"
# 00477:   },
# 00478:   {
# 00479:     "op": "replace",
# 00480:     "path": "/ControlModuleVoltage",
# 00481:     "value": 68.70092140384853
# 00482:   },
# 00483:   {
# 00484:     "op": "replace",
# 00485:     "path": "/TraveledDistanceSinceStart",
# 00486:     "value": 78.93365777432213
# 00487:   },
# 00488:   {
# 00489:     "op": "replace",
# 00490:     "path": "/CommandedEVAP",
# 00491:     "value": 83.6401472567999
# 00492:   },
# 00493:   {
# 00494:     "op": "replace",
# 00495:     "path": "/TPS",
# 00496:     "value": 20
# 00497:   },
# 00498:   {
# 00499:     "op": "replace",
# 00500:     "path": "/StartTime",
# 00501:     "value": "ivvlfxsxpe"
# 00502:   },
# 00503:   {
# 00504:     "op": "replace",
# 00505:     "path": "/AngularVelocity/Pitch",
# 00506:     "value": 78.28293945240141
# 00507:   },
# 00508:   {
# 00509:     "op": "replace",
# 00510:     "path": "/EGRError",
# 00511:     "value": 67.85796530834189
# 00512:   },
# 00513:   {
# 00514:     "op": "replace",
# 00515:     "path": "/Hazard/IsDefect",
# 00516:     "value": false
# 00517:   },
# 00518:   {
# 00519:     "op": "replace",
# 00520:     "path": "/IsForwardEngaged",
# 00521:     "value": false
# 00522:   },
# 00523:   {
# 00524:     "op": "replace",
# 00525:     "path": "/LongTermFuelTrim2",
# 00526:     "value": 61.11544998467045
# 00527:   },
# 00528:   {
# 00529:     "op": "replace",
# 00530:     "path": "/WheelWidth",
# 00531:     "value": 50.27615596616863
# 00532:   },
# 00533:   {
# 00534:     "op": "replace",
# 00535:     "path": "/Light/AmbientLight/Row1/DriverSide/Color",
# 00536:     "value": "fzusnmlunz"
# 00537:   },
# 00538:   {
# 00539:     "op": "replace",
# 00540:     "path": "/HVAC/AmbientAirTemperature",
# 00541:     "value": 82.8423892543812
# 00542:   },
# 00543:   {
# 00544:     "op": "replace",
# 00545:     "path": "/GrossCapacity",
# 00546:     "value": 71
# 00547:   },
# 00548:   {
# 00549:     "op": "replace",
# 00550:     "path": "/PidsA",
# 00551:     "value": "fdlttdqnin"
# 00552:   },
# 00553:   {
# 00554:     "op": "replace",
# 00555:     "path": "/AccumulatedChargedThroughput",
# 00556:     "value": 99.77394298557243
# 00557:   },
# 00558:   {
# 00559:     "op": "replace",
# 00560:     "path": "/Width",
# 00561:     "value": 11
# 00562:   },
# 00563:   {
# 00564:     "op": "replace",
# 00565:     "path": "/MaxPower",
# 00566:     "value": 57.33723753687341
# 00567:   },
# 00568:   {
# 00569:     "op": "replace",
# 00570:     "path": "/RunTimeMIL",
# 00571:     "value": 8.077874557309483
# 00572:   },
# 00573:   {
# 00574:     "op": "replace",
# 00575:     "path": "/Fog/Front/IsDefect",
# 00576:     "value": true
# 00577:   },
# 00578:   {
# 00579:     "op": "replace",
# 00580:     "path": "/DeclinedURI",
# 00581:     "value": "cajiwcuzwu"
# 00582:   },
# 00583:   {
# 00584:     "op": "replace",
# 00585:     "path": "/MaxTowBallWeight",
# 00586:     "value": 93
# 00587:   },
# 00588:   {
# 00589:     "op": "replace",
# 00590:     "path": "/IdleHours",
# 00591:     "value": 66.89386502573433
# 00592:   },
# 00593:   {
# 00594:     "op": "replace",
# 00595:     "path": "/IsChargingCableConnected",
# 00596:     "value": true
# 00597:   }
# 00598: ]

# %%
# Save to file
first.save('./first.json')
second.save('./second.json')

# %%
patch.save('./patch.json')
