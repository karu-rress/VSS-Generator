# %% [markdown]
# ## generator.ipynb
#
# Random VSS generator

# %%
# import necessary libraries
import json
import random

# %%
class vss_json:
    """VSS JSON manager class"""
        
    def __init__(self, **kwargs):
        """
        Initialize VSS JSON data
        
        :param kwargs: EITHER of the following is required
            - file: JSON file to load
            - data: JSON data (for internal use)
        """
        assert 'file' in kwargs or 'data' in kwargs
        self.initialized = False        
        
        if 'file' in kwargs:
            with open(kwargs['file'], 'r') as f:
                self.data = json.load(f)  
            self.remove_key('description', 'uuid', 'type', 'comment', 'deprecated')
        elif 'data' in kwargs:
            self.data = kwargs['data']
            self.initialized = True
        else:
            raise ValueError('Either file or data must be provided')
        
    def print(self, indent: int=4, with_index: bool=False) -> None:
        """Print JSON data"""
        txt = json.dumps(self.data, indent=indent)
        if with_index:
            for i, line in enumerate(txt.split('\n'), 1):
                print(f'{i:05d}: {line}')
        else:
            print(txt)
        
    def remove_key(self, *keys: str) -> None:
        """
        Remove keys from JSON data recursively
        
        :param keys: Keys to remove
        """
        for leaf, _ in self.leaf_nodes():
            for key in keys:
                if key in leaf:
                    del leaf[key]
            
    def leaf_nodes(self, data=None, parent_key=''):
        """
        Traverse and yield all leaf values (dict/scaler) in JSON data
        
        :param data: JSON data to traverse (default: self.data)
        :param parent_key: Parent key to track the hierarchy (for debugging and display purposes)
        """
        if data is None:
            data = self.data
        
        if not self.initialized:
            if isinstance(data, dict):
                is_leaf = all(not isinstance(value, dict) for value in data.values())
                if is_leaf:
                    yield data, parent_key
                else:
                    for key, value in data.items():
                        yield from self.leaf_nodes(value, parent_key + '.' + key if parent_key else key)
            elif isinstance(data, list):
                for index, item in enumerate(data):
                    yield from self.leaf_nodes(item, parent_key + f'[{index}]')
        else:
            if isinstance(data, dict):
                for key, value in data.items():
                    yield from self.leaf_nodes(value, parent_key + '.' + key if parent_key else key)
            elif isinstance(data, list):
                for index, item in enumerate(data):
                    yield data, parent_key
            else:
                yield data, parent_key
                
    
    def generate(self, dataset_size: float=1.0) -> 'vss_json':
        """
        Generate an initial random dataset based on the JSON schema
        
        :param dataset_size: Dataset size ratio [0.0, 1.0]
        """
        result = {}
        
        for leaf, parent in self.leaf_nodes():
            # !! only add the node by dataset_size
            if random.random() > dataset_size:
                continue
            
            # step 1: set parent (without 'children' dictionary)
            hierarchy = [x for x in parent.split('.') if x != 'children']
            new = result
            for idx, node in enumerate(hierarchy):
                if node not in new:
                    new[node] = {}
                    if idx == len(hierarchy) - 1:
                        break
                    new = new[node]
                
            # step 2: set leaf by 'datatype'
            dtype = leaf['datatype']
            if dtype == 'boolean':
                new[node] = random.choice([True, False])
            elif dtype in ['int8', 'uint8', 'float'] and \
                'unit' in leaf and leaf['unit'] == 'percent':
                new[node] = random.random() * 100
                if dtype != 'float':
                    new[node] = int(new[node])
            elif 'allowed' in leaf:
                new[node] = random.choice(leaf['allowed'])
            elif dtype == 'double' or dtype == 'float':
                new[node] = random.random() * 100
            elif dtype == 'float[]':
                new[node] = []
                for i in range(random.randint(1, 5)):
                    new[node].append(random.random() * 100)
            elif dtype in ['int8', 'int16', 'int32']:
                new[node] = random.randint(-100, 100)
            elif dtype == 'string':
                # generate random str`ing
                new[node] = ''.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=10))
            elif dtype == 'string[]':
                new[node] = []
                for i in range(random.randint(1, 5)):
                    new[node].append(''.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=10)))
            elif dtype in ['uint8', 'uint16', 'uint32']:
                new[node] = random.randint(0, 100)
            elif dtype == 'uint8[]':
                new[node] = []
                for i in range(random.randint(1, 5)):
                    new[node].append(random.randint(0, 100))
                    
            # step 3: set the leaf
        
        return vss_json(data=result)
    
    def generate_next(self, change_rate):
        assert self.initialized, 'vss_json must be initialized with generate()'
        
        result = {}
        for leaf_data, parent in self.leaf_nodes():
            hierarchy = [x for x in parent.split('.') if x != 'children']
            current = result
            for idx, node in enumerate(hierarchy):
                if node not in current:
                    current[node] = {}
                    if idx == len(hierarchy) - 1:
                        break
                    current = current[node]
                    
            if isinstance(leaf_data, list):
                current[node] = leaf_data[:]
                continue        
            
            if random.random() > change_rate:
                current[node] = leaf_data
                continue
            
            match leaf_data:
                case str():
                    current[node] = ''.join(random.choices('abcdefghijklmnopqrstuvwxyz', k=10))
                case bool():
                    current[node] = not leaf_data
                case int():
                    current[node] = random.randint(0, 100)
                case float():
                    current[node] = random.random() * 100
        return vss_json(data=result)
    
    def save(self, file: str) -> None:
        """Save JSON data to file"""
        with open(file, 'w') as f:
            json.dump(self.data, f, indent=4)

# %%
vss = vss_json(file='./vss_rel_4.2.json')

# %%
# JSON 내용 확인
# vss.print(2, True)

# %%
# Generate initial random dataset
first = vss.generate(1.0)
first.print(2, True)
# Out:
# 00001: {
# 00002:   "Vehicle": {
# 00003:     "ADAS": {
# 00004:       "ABS": {
# 00005:         "IsEnabled": false
# 00006:       }
# 00007:     }
# 00008:   },
# 00009:   "ADAS": {
# 00010:     "ABS": {
# 00011:       "IsEngaged": false
# 00012:     }
# 00013:   },
# 00014:   "ABS": {
# 00015:     "IsError": false
# 00016:   },
# 00017:   "ActiveAutonomyLevel": "SAE_3_DISENGAGING",
# 00018:   "CruiseControl": {
# 00019:     "IsActive": true
# 00020:   },
# 00021:   "IsEnabled": true,
# 00022:   "IsError": true,
# 00023:   "SpeedSet": 0.42242595009084694,
# 00024:   "DMS": {
# 00025:     "IsEnabled": false
# 00026:   },
# 00027:   "IsWarning": false,
# 00028:   "EBA": {
# 00029:     "IsEnabled": false
# 00030:   },
# 00031:   "IsEngaged": true,
# 00032:   "EBD": {
# 00033:     "IsEnabled": false
# 00034:   },
# 00035:   "ESC": {
# 00036:     "IsEnabled": false
# 00037:   },
# 00038:   "IsStrongCrossWindDetected": false,
# 00039:   "RoadFriction": {
# 00040:     "LowerBound": 20.25191170137296
# 00041:   },
# 00042:   "MostProbable": 41.461939552157155,
# 00043:   "UpperBound": 54.70192603489157,
# 00044:   "IsAutoPowerOptimize": false,
# 00045:   "LaneDepartureDetection": {
# 00046:     "IsEnabled": true
# 00047:   },
# 00048:   "ObstacleDetection": {
# 00049:     "IsEnabled": false
# 00050:   },
# 00051:   "PowerOptimizeLevel": 35,
# 00052:   "SupportedAutonomyLevel": "SAE_4",
# 00053:   "TCS": {
# 00054:     "IsEnabled": false
# 00055:   },
# 00056:   "Acceleration": {
# 00057:     "Lateral": 0.8711425245136046
# 00058:   },
# 00059:   "Longitudinal": 0.8909419878935876,
# 00060:   "Vertical": 0.1844083543073124,
# 00061:   "AngularVelocity": {
# 00062:     "Pitch": 0.4763631781558625
# 00063:   },
# 00064:   "Roll": 0.38064287179128553,
# 00065:   "Yaw": 0.7629865900023821,
# 00066:   "AverageSpeed": 0.44339237694281786,
# 00067:   "Body": {
# 00068:     "BodyType": "ixkmuivwlk"
# 00069:   },
# 00070:   "Hood": {
# 00071:     "IsOpen": true
# 00072:   },
# 00073:   "Position": 92,
# 00074:   "Switch": "CLOSE",
# 00075:   "Horn": {
# 00076:     "IsActive": false
# 00077:   },
# 00078:   "Lights": {
# 00079:     "Backup": {
# 00080:       "IsDefect": false
# 00081:     }
# 00082:   },
# 00083:   "Backup": {
# 00084:     "IsOn": false
# 00085:   },
# 00086:   "Beam": {
# 00087:     "High": {
# 00088:       "IsDefect": true
# 00089:     }
# 00090:   },
# 00091:   "High": {
# 00092:     "IsOn": true
# 00093:   },
# 00094:   "Low": {
# 00095:     "IsDefect": true
# 00096:   },
# 00097:   "IsOn": true,
# 00098:   "Brake": {
# 00099:     "IsActive": "ADAPTIVE"
# 00100:   },
# 00101:   "IsDefect": false,
# 00102:   "DirectionIndicator": {
# 00103:     "Left": {
# 00104:       "IsDefect": false
# 00105:     }
# 00106:   },
# 00107:   "Left": {
# 00108:     "IsSignaling": true
# 00109:   },
# 00110:   "Right": {
# 00111:     "IsDefect": false
# 00112:   },
# 00113:   "IsSignaling": false,
# 00114:   "Fog": {
# 00115:     "Front": {
# 00116:       "IsDefect": false
# 00117:     }
# 00118:   },
# 00119:   "Front": {
# 00120:     "IsOn": false
# 00121:   },
# 00122:   "Rear": {
# 00123:     "IsDefect": false
# 00124:   },
# 00125:   "Hazard": {
# 00126:     "IsDefect": true
# 00127:   },
# 00128:   "IsHighBeamSwitchOn": true,
# 00129:   "LicensePlate": "vlrzwcujei",
# 00130:   "LightSwitch": "OFF",
# 00131:   "Parking": {
# 00132:     "IsDefect": true
# 00133:   },
# 00134:   "Running": {
# 00135:     "IsDefect": false
# 00136:   },
# 00137:   "Mirrors": {
# 00138:     "DriverSide": {
# 00139:       "IsFolded": true
# 00140:     }
# 00141:   },
# 00142:   "DriverSide": {
# 00143:     "IsHeatingOn": false
# 00144:   },
# 00145:   "IsLocked": false,
# 00146:   "Pan": 2,
# 00147:   "Tilt": 35,
# 00148:   "PassengerSide": {
# 00149:     "IsFolded": false
# 00150:   },
# 00151:   "IsHeatingOn": false,
# 00152:   "Raindetection": {
# 00153:     "Intensity": 74
# 00154:   },
# 00155:   "RearMainSpoilerPosition": 74.22863879620571,
# 00156:   "RefuelPosition": "FRONT_LEFT",
# 00157:   "Trunk": {
# 00158:     "Front": {
# 00159:       "IsLightOn": false
# 00160:     }
# 00161:   },
# 00162:   "IsOpen": true,
# 00163:   "IsLightOn": true,
# 00164:   "Windshield": {
# 00165:     "Front": {
# 00166:       "IsHeatingOn": false
# 00167:     }
# 00168:   },
# 00169:   "WasherFluid": {
# 00170:     "IsLevelLow": false
# 00171:   },
# 00172:   "Level": "NORMAL",
# 00173:   "Wiping": {
# 00174:     "Intensity": 50
# 00175:   },
# 00176:   "IsWipersWorn": false,
# 00177:   "Mode": "MANUAL",
# 00178:   "System": {
# 00179:     "ActualPosition": 0.2596638086033797
# 00180:   },
# 00181:   "DriveCurrent": 0.4189692645732862,
# 00182:   "Frequency": 44,
# 00183:   "IsBlocked": true,
# 00184:   "IsEndingWipeCycle": false,
# 00185:   "IsOverheated": false,
# 00186:   "IsPositionReached": true,
# 00187:   "IsWiperError": false,
# 00188:   "IsWiping": false,
# 00189:   "TargetPosition": 0.7028060322416165,
# 00190:   "WiperWear": 66,
# 00191:   "IsLevelLow": true,
# 00192:   "Intensity": 92,
# 00193:   "ActualPosition": 0.1705006767954308,
# 00194:   "Cabin": {
# 00195:     "Convertible": {
# 00196:       "Status": "CLOSED"
# 00197:     }
# 00198:   },
# 00199:   "Door": {
# 00200:     "Row1": {
# 00201:       "DriverSide": {
# 00202:         "IsChildLockActive": false
# 00203:       }
# 00204:     }
# 00205:   },
# 00206:   "Row1": {
# 00207:     "DriverSide": {
# 00208:       "IsLocked": true
# 00209:     }
# 00210:   },
# 00211:   "Shade": {
# 00212:     "IsOpen": false
# 00213:   },
# 00214:   "Window": {
# 00215:     "IsOpen": false
# 00216:   },
# 00217:   "IsChildLockActive": true,
# 00218:   "Row2": {
# 00219:     "DriverSide": {
# 00220:       "IsChildLockActive": true
# 00221:     }
# 00222:   },
# 00223:   "DoorCount": 100,
# 00224:   "DriverPosition": "RIGHT",
# 00225:   "HVAC": {
# 00226:     "AmbientAirTemperature": 0.3325706115176509
# 00227:   },
# 00228:   "IsAirConditioningActive": true,
# 00229:   "IsFrontDefrosterActive": false,
# 00230:   "IsRearDefrosterActive": true,
# 00231:   "IsRecirculationActive": false,
# 00232:   "Station": {
# 00233:     "Row1": {
# 00234:       "Driver": {
# 00235:         "AirDistribution": "MIDDLE"
# 00236:       }
# 00237:     }
# 00238:   },
# 00239:   "Driver": {
# 00240:     "FanSpeed": 47
# 00241:   },
# 00242:   "Temperature": 19,
# 00243:   "Passenger": {
# 00244:     "AirDistribution": "MIDDLE"
# 00245:   },
# 00246:   "FanSpeed": 39,
# 00247:   "AirDistribution": "DOWN",
# 00248:   "Row3": {
# 00249:     "Driver": {
# 00250:       "AirDistribution": "MIDDLE"
# 00251:     }
# 00252:   },
# 00253:   "Row4": {
# 00254:     "Driver": {
# 00255:       "AirDistribution": "UP"
# 00256:     }
# 00257:   },
# 00258:   "Infotainment": {
# 00259:     "HMI": {
# 00260:       "Brightness": 70.24516237526844
# 00261:     }
# 00262:   },
# 00263:   "HMI": {
# 00264:     "CurrentLanguage": "fpskgxvixy"
# 00265:   },
# 00266:   "DateFormat": "MM_DD_YYYY",
# 00267:   "DayNightMode": "DAY",
# 00268:   "DisplayOffDuration": 95,
# 00269:   "DistanceUnit": "MILES",
# 00270:   "EVEconomyUnits": "WATT_HOURS_PER_MILE",
# 00271:   "EVEnergyUnits": "AMPERE_HOURS",
# 00272:   "FontSize": "LARGE",
# 00273:   "FuelEconomyUnits": "LITERS_PER_100_KILOMETERS",
# 00274:   "FuelVolumeUnit": "GALLON_US",
# 00275:   "IsScreenAlwaysOn": false,
# 00276:   "LastActionTime": "hounoofwbq",
# 00277:   "SpeedUnit": "KILOMETERS_PER_HOUR",
# 00278:   "TemperatureUnit": "F",
# 00279:   "TimeFormat": "HR_12",
# 00280:   "TirePressureUnit": "KPA",
# 00281:   "Media": {
# 00282:     "Action": "UNKNOWN"
# 00283:   },
# 00284:   "DeclinedURI": "dhtgfgluxx",
# 00285:   "Played": {
# 00286:     "Album": "dqmqjfdxwv"
# 00287:   },
# 00288:   "Artist": "urbfrvgleq",
# 00289:   "PlaybackRate": 0.053884377262307326,
# 00290:   "Source": "WIFI",
# 00291:   "Track": "yzswsdsbxx",
# 00292:   "URI": "cyzgdzwfyf",
# 00293:   "SelectedURI": "pcekonesqm",
# 00294:   "Volume": 22,
# 00295:   "Navigation": {
# 00296:     "DestinationSet": {
# 00297:       "Latitude": 0.3839402721827986
# 00298:     }
# 00299:   },
# 00300:   "DestinationSet": {
# 00301:     "Longitude": 0.24268404668883825
# 00302:   },
# 00303:   "GuidanceVoice": "ETC",
# 00304:   "Map": {
# 00305:     "IsAutoScaleModeUsed": true
# 00306:   },
# 00307:   "Mute": "ALERT_ONLY",
# 00308:   "SmartphoneProjection": {
# 00309:     "Active": "ACTIVE"
# 00310:   },
# 00311:   "SupportedMode": "APPLE_CARPLAY",
# 00312:   "SmartphoneScreenMirroring": {
# 00313:     "Active": "ACTIVE"
# 00314:   },
# 00315:   "IsWindowChildLockEngaged": false,
# 00316:   "Light": {
# 00317:     "AmbientLight": {
# 00318:       "Row1": {
# 00319:         "DriverSide": {
# 00320:           "Color": "zpgflcpbnd"
# 00321:         }
# 00322:       }
# 00323:     }
# 00324:   },
# 00325:   "AmbientLight": {
# 00326:     "Row1": {
# 00327:       "DriverSide": {
# 00328:         "Intensity": 76
# 00329:       }
# 00330:     }
# 00331:   },
# 00332:   "Color": "vzftubiqey",
# 00333:   "InteractiveLightBar": {
# 00334:     "Color": "zfctlyatmz"
# 00335:   },
# 00336:   "Effect": "byiswhpbqq",
# 00337:   "IsDomeOn": true,
# 00338:   "IsGloveBoxOn": false,
# 00339:   "PerceivedAmbientLight": 0,
# 00340:   "Spotlight": {
# 00341:     "Row1": {
# 00342:       "DriverSide": {
# 00343:         "Color": "yqvyxhaida"
# 00344:       }
# 00345:     }
# 00346:   },
# 00347:   "RearShade": {
# 00348:     "IsOpen": true
# 00349:   },
# 00350:   "RearviewMirror": {
# 00351:     "DimmingLevel": 44
# 00352:   },
# 00353:   "Seat": {
# 00354:     "Row1": {
# 00355:       "DriverSide": {
# 00356:         "Airbag": {
# 00357:           "IsDeployed": false
# 00358:         }
# 00359:       }
# 00360:     }
# 00361:   },
# 00362:   "Backrest": {
# 00363:     "Lumbar": {
# 00364:       "Height": 34
# 00365:     }
# 00366:   },
# 00367:   "Lumbar": {
# 00368:     "Support": 30.521762989163737
# 00369:   },
# 00370:   "Recline": 0.2764398712085626,
# 00371:   "SideBolster": {
# 00372:     "Support": 8.7469153965536
# 00373:   },
# 00374:   "Headrest": {
# 00375:     "Angle": 0.8900558502101554
# 00376:   },
# 00377:   "Height": 4,
# 00378:   "Heating": 86,
# 00379:   "HeatingCooling": 1,
# 00380:   "IsBelted": false,
# 00381:   "IsOccupied": false,
# 00382:   "Massage": 73,
# 00383:   "Occupant": {
# 00384:     "Identifier": {
# 00385:       "Issuer": "ymejzmhupm"
# 00386:     }
# 00387:   },
# 00388:   "Identifier": {
# 00389:     "Subject": "unmmoyyqvx"
# 00390:   },
# 00391:   "SeatBeltHeight": 54,
# 00392:   "Seating": {
# 00393:     "Length": 41
# 00394:   },
# 00395:   "IsReclineBackwardEngaged": true,
# 00396:   "IsReclineForwardEngaged": true,
# 00397:   "IsDownEngaged": true,
# 00398:   "IsLessSupportEngaged": false,
# 00399:   "IsMoreSupportEngaged": true,
# 00400:   "IsUpEngaged": true,
# 00401:   "IsBackwardEngaged": false,
# 00402:   "IsForwardEngaged": true,
# 00403:   "IsCoolerEngaged": true,
# 00404:   "IsTiltBackwardEngaged": false,
# 00405:   "IsTiltForwardEngaged": true,
# 00406:   "IsWarmerEngaged": false,
# 00407:   "IsDecreaseEngaged": false,
# 00408:   "IsIncreaseEngaged": false,
# 00409:   "Middle": {
# 00410:     "Airbag": {
# 00411:       "IsDeployed": false
# 00412:     }
# 00413:   },
# 00414:   "Support": 47.03683451261803,
# 00415:   "Angle": 0.3231054580011058,
# 00416:   "Issuer": "tlkdyzddfa",
# 00417:   "Subject": "qcxpgwvveb",
# 00418:   "Length": 76,
# 00419:   "Airbag": {
# 00420:     "IsDeployed": false
# 00421:   },
# 00422:   "IsDeployed": false,
# 00423:   "SeatPosCount": [
# 00424:     14,
# 00425:     53,
# 00426:     88,
# 00427:     4
# 00428:   ],
# 00429:   "SeatRowCount": 48,
# 00430:   "Sunroof": {
# 00431:     "Position": 52
# 00432:   },
# 00433:   "CargoVolume": 0.23204320766695763,
# 00434:   "Chassis": {
# 00435:     "Accelerator": {
# 00436:       "PedalPosition": 7
# 00437:     }
# 00438:   },
# 00439:   "Axle": {
# 00440:     "Row1": {
# 00441:       "AxleWidth": 97
# 00442:     }
# 00443:   },
# 00444:   "SteeringAngle": 0.9142314385229335,
# 00445:   "TireAspectRatio": 4,
# 00446:   "TireDiameter": 0.7884211134506436,
# 00447:   "TireWidth": 33,
# 00448:   "TrackWidth": 87,
# 00449:   "TreadWidth": 15,
# 00450:   "Wheel": {
# 00451:     "Left": {
# 00452:       "AngularSpeed": 0.007828115974766736
# 00453:     }
# 00454:   },
# 00455:   "FluidLevel": 67,
# 00456:   "IsBrakesWorn": false,
# 00457:   "IsFluidLevelLow": false,
# 00458:   "PadWear": 80,
# 00459:   "Speed": 0.5614743019994328,
# 00460:   "Tire": {
# 00461:     "IsPressureLow": true
# 00462:   },
# 00463:   "Pressure": 46,
# 00464:   "AngularSpeed": 0.5575073192399513,
# 00465:   "IsPressureLow": false,
# 00466:   "WheelCount": 67,
# 00467:   "WheelDiameter": 0.635507721318149,
# 00468:   "WheelWidth": 0.2757631564818487,
# 00469:   "AxleWidth": 13,
# 00470:   "AxleCount": 64,
# 00471:   "IsDriverEmergencyBrakingDetected": false,
# 00472:   "PedalPosition": 26,
# 00473:   "ParkingBrake": {
# 00474:     "IsAutoApplyEnabled": true
# 00475:   },
# 00476:   "SteeringWheel": {
# 00477:     "Angle": -26
# 00478:   },
# 00479:   "Extension": 15,
# 00480:   "Wheelbase": 62,
# 00481:   "Connectivity": {
# 00482:     "IsConnectivityAvailable": false
# 00483:   },
# 00484:   "CurbWeight": 63,
# 00485:   "CurrentLocation": {
# 00486:     "Altitude": 0.8297770370082465
# 00487:   },
# 00488:   "GNSSReceiver": {
# 00489:     "FixType": "THREE_D_SATELLITE_AND_GROUND_BASED_AUGMENTATION"
# 00490:   },
# 00491:   "MountingPosition": {
# 00492:     "X": 62
# 00493:   },
# 00494:   "Y": -96,
# 00495:   "Z": -16,
# 00496:   "Heading": 0.906773164155177,
# 00497:   "HorizontalAccuracy": 0.9298393144373516,
# 00498:   "Latitude": 0.670425835413727,
# 00499:   "Longitude": 0.5730612987203597,
# 00500:   "Timestamp": "jredvqjpij",
# 00501:   "VerticalAccuracy": 0.6264916786996301,
# 00502:   "CurrentOverallWeight": 40,
# 00503:   "Diagnostics": {
# 00504:     "DTCCount": 31
# 00505:   },
# 00506:   "DTCList": [
# 00507:     "kbvujiaujs",
# 00508:     "wmuqetndfj",
# 00509:     "qiypxhcndi",
# 00510:     "tcqbcwbtaw"
# 00511:   ],
# 00512:   "AttentiveProbability": 34.67412673760607,
# 00513:   "DistractionLevel": 70.79703135223015,
# 00514:   "FatigueLevel": 93.960041316164,
# 00515:   "HeartRate": 57,
# 00516:   "IsEyesOnRoad": false,
# 00517:   "IsHandsOnWheel": true,
# 00518:   "EmissionsCO2": 77,
# 00519:   "Exterior": {
# 00520:     "AirTemperature": 0.020686980470541294
# 00521:   },
# 00522:   "Humidity": 45.35630056538689,
# 00523:   "LightIntensity": 71.8407938384064,
# 00524:   "GrossWeight": 52,
# 00525:   "IsBrokenDown": true,
# 00526:   "IsMoving": true,
# 00527:   "LowVoltageBattery": {
# 00528:     "CurrentCurrent": 0.9237752618932208
# 00529:   },
# 00530:   "CurrentVoltage": 0.7757178545433862,
# 00531:   "NominalCapacity": 7,
# 00532:   "NominalVoltage": 2,
# 00533:   "LowVoltageSystemState": "UNDEFINED",
# 00534:   "MaxTowBallWeight": 86,
# 00535:   "MaxTowWeight": 97,
# 00536:   "OBD": {
# 00537:     "AbsoluteLoad": 3.825525999192936
# 00538:   },
# 00539:   "AcceleratorPositionD": 68.58565474834501,
# 00540:   "AcceleratorPositionE": 58.759085188653295,
# 00541:   "AcceleratorPositionF": 4.300981649173819,
# 00542:   "AirStatus": "leidxesfnp",
# 00543:   "AmbientAirTemperature": 0.3786537862841515,
# 00544:   "BarometricPressure": 0.3290990382113872,
# 00545:   "Catalyst": {
# 00546:     "Bank1": {
# 00547:       "Temperature1": 0.1967569362106515
# 00548:     }
# 00549:   },
# 00550:   "Bank1": {
# 00551:     "Temperature2": 0.8167012014064507
# 00552:   },
# 00553:   "Bank2": {
# 00554:     "Temperature1": 0.23283518712115203
# 00555:   },
# 00556:   "Temperature2": 0.04398388834024636,
# 00557:   "CommandedEGR": 56.16646967024076,
# 00558:   "CommandedEVAP": 88.75195740043658,
# 00559:   "CommandedEquivalenceRatio": 0.8887962256846716,
# 00560:   "ControlModuleVoltage": 0.9914139655006884,
# 00561:   "CoolantTemperature": 0.18992341771608756,
# 00562:   "DistanceSinceDTCClear": 0.554233464647845,
# 00563:   "DistanceWithMIL": 0.9028761085941921,
# 00564:   "DriveCycleStatus": {
# 00565:     "DTCCount": 78
# 00566:   },
# 00567:   "IgnitionType": "COMPRESSION",
# 00568:   "IsMILOn": true,
# 00569:   "EGRError": 28.051498597088266,
# 00570:   "EVAPVaporPressure": 0.01643662964917192,
# 00571:   "EVAPVaporPressureAbsolute": 0.28017225396549594,
# 00572:   "EVAPVaporPressureAlternate": 0.9857743092871849,
# 00573:   "EngineLoad": 89.38280673757573,
# 00574:   "EngineSpeed": 0.0961900890145524,
# 00575:   "EthanolPercent": 63.33591030947746,
# 00576:   "FreezeDTC": "iwabrlikdf",
# 00577:   "FuelInjectionTiming": 0.31995916097855515,
# 00578:   "FuelLevel": 27.703446876985637,
# 00579:   "FuelPressure": 0.7574897560576961,
# 00580:   "FuelRailPressureAbsolute": 0.4529721322769549,
# 00581:   "FuelRailPressureDirect": 0.21688913641477126,
# 00582:   "FuelRailPressureVac": 0.842891635170489,
# 00583:   "FuelRate": 0.43926392941717707,
# 00584:   "FuelStatus": "jrjdkywaio",
# 00585:   "FuelType": 59,
# 00586:   "HybridBatteryRemaining": 94.1608993396703,
# 00587:   "IntakeTemp": 0.6615758677387363,
# 00588:   "IsPTOActive": false,
# 00589:   "LongTermFuelTrim1": 85.03412854232293,
# 00590:   "LongTermFuelTrim2": 26.492786566794514,
# 00591:   "LongTermO2Trim1": 58.14043893149432,
# 00592:   "LongTermO2Trim2": 89.08963663032527,
# 00593:   "LongTermO2Trim3": 89.3267426249634,
# 00594:   "LongTermO2Trim4": 33.571969628657975,
# 00595:   "MAF": 54,
# 00596:   "MAP": 52,
# 00597:   "MaxMAF": 0.9141141403567303,
# 00598:   "O2": {
# 00599:     "Sensor1": {
# 00600:       "ShortTermFuelTrim": 13.760640648286415
# 00601:     }
# 00602:   },
# 00603:   "Sensor1": {
# 00604:     "Voltage": 0.05310858657148254
# 00605:   },
# 00606:   "Sensor2": {
# 00607:     "ShortTermFuelTrim": 23.870973328343503
# 00608:   },
# 00609:   "Voltage": 0.12816965355598964,
# 00610:   "Sensor3": {
# 00611:     "ShortTermFuelTrim": 66.33632588779169
# 00612:   },
# 00613:   "Sensor4": {
# 00614:     "ShortTermFuelTrim": 56.937460388974706
# 00615:   },
# 00616:   "Sensor5": {
# 00617:     "ShortTermFuelTrim": 7.143613275119886
# 00618:   },
# 00619:   "Sensor6": {
# 00620:     "ShortTermFuelTrim": 18.116805432069892
# 00621:   },
# 00622:   "Sensor7": {
# 00623:     "ShortTermFuelTrim": 24.784371179978837
# 00624:   },
# 00625:   "Sensor8": {
# 00626:     "ShortTermFuelTrim": 47.66226904766615
# 00627:   },
# 00628:   "O2WR": {
# 00629:     "Sensor1": {
# 00630:       "Current": 0.39386873867777195
# 00631:     }
# 00632:   },
# 00633:   "Lambda": 0.30590241367773896,
# 00634:   "Current": 0.6594610062647946,
# 00635:   "OBDStandards": 16,
# 00636:   "OilTemperature": 0.5810564263009992,
# 00637:   "OxygenSensorsIn2Banks": 50,
# 00638:   "OxygenSensorsIn4Banks": 34,
# 00639:   "PidsA": "1C",
# 00640:   "PidsB": "27",
# 00641:   "PidsC": "48",
# 00642:   "RelativeAcceleratorPosition": 91.07288689161126,
# 00643:   "RelativeThrottlePosition": 67.85835486128123,
# 00644:   "RunTime": 0.8552839963582203,
# 00645:   "RunTimeMIL": 0.8906936832432695,
# 00646:   "ShortTermFuelTrim1": 93.10236327128473,
# 00647:   "ShortTermFuelTrim2": 84.77972027816676,
# 00648:   "ShortTermO2Trim1": 13.021210580830944,
# 00649:   "ShortTermO2Trim2": 46.127519593178214,
# 00650:   "ShortTermO2Trim3": 84.07716215969847,
# 00651:   "ShortTermO2Trim4": 67.34431436729834,
# 00652:   "Status": {
# 00653:     "DTCCount": 28
# 00654:   },
# 00655:   "ThrottleActuator": 1.3906618478059296,
# 00656:   "ThrottlePosition": 93.22033547978815,
# 00657:   "ThrottlePositionB": 71.08763187277016,
# 00658:   "ThrottlePositionC": 19.509939679419354,
# 00659:   "TimeSinceDTCCleared": 0.6816916002107282,
# 00660:   "TimingAdvance": 0.8042689041627058,
# 00661:   "WarmupsSinceDTCClear": 67,
# 00662:   "HeadPosition": {
# 00663:     "Pitch": 0.32498908973836915
# 00664:   },
# 00665:   "X": 100,
# 00666:   "MidEyeGaze": {
# 00667:     "Azimuth": 0.3779424218362999
# 00668:   },
# 00669:   "Elevation": 0.7239356863129064,
# 00670:   "Pitch": 0.6669270427535521,
# 00671:   "Azimuth": 0.9825266714077051,
# 00672:   "Powertrain": {
# 00673:     "AccumulatedBrakingEnergy": 0.921432093599458
# 00674:   },
# 00675:   "CombustionEngine": {
# 00676:     "AspirationType": "NATURAL"
# 00677:   },
# 00678:   "Bore": 0.9968235406002539,
# 00679:   "CompressionRatio": "ypxqalxkfy",
# 00680:   "Configuration": "SQUARE",
# 00681:   "DieselExhaustFluid": {
# 00682:     "Capacity": 0.22632073030431532
# 00683:   },
# 00684:   "Range": 53,
# 00685:   "DieselParticulateFilter": {
# 00686:     "DeltaPressure": 0.3164281958299394
# 00687:   },
# 00688:   "InletTemperature": 0.577559099089194,
# 00689:   "OutletTemperature": 0.6805616824579959,
# 00690:   "Displacement": 63,
# 00691:   "ECT": 98,
# 00692:   "EOP": 59,
# 00693:   "EOT": 60,
# 00694:   "EngineCode": "wuckmzwyud",
# 00695:   "EngineCoolant": {
# 00696:     "Capacity": 0.8412211741868943
# 00697:   },
# 00698:   "LifeRemaining": -9,
# 00699:   "EngineCoolantCapacity": 0.20363321376375543,
# 00700:   "EngineHours": 0.07740736729990094,
# 00701:   "EngineOil": {
# 00702:     "Capacity": 0.3477819651456522
# 00703:   },
# 00704:   "EngineOilCapacity": 0.14877628843634894,
# 00705:   "EngineOilLevel": "CRITICALLY_LOW",
# 00706:   "IdleHours": 0.08502904789699217,
# 00707:   "IsRunning": false,
# 00708:   "MaxPower": 0.8612862704423802,
# 00709:   "MaxTorque": 52,
# 00710:   "NumberOfCylinders": 53,
# 00711:   "NumberOfValvesPerCylinder": 50,
# 00712:   "OilLifeRemaining": 16,
# 00713:   "Power": -78,
# 00714:   "StrokeLength": 0.03708916875449508,
# 00715:   "TPS": 28,
# 00716:   "Torque": 71,
# 00717:   "ElectricMotor": {
# 00718:     "CoolantTemperature": 36
# 00719:   },
# 00720:   "Capacity": 0.744467375824308,
# 00721:   "MaxRegenPower": 72,
# 00722:   "MaxRegenTorque": 38,
# 00723:   "TimeInUse": 0.005383619938544193,
# 00724:   "FuelSystem": {
# 00725:     "AbsoluteLevel": 0.37715712108170085
# 00726:   },
# 00727:   "AverageConsumption": 0.7536935597044833,
# 00728:   "ConsumptionSinceStart": 0.7890852641371363,
# 00729:   "HybridType": "CIMG",
# 00730:   "InstantConsumption": 0.6585714936792711,
# 00731:   "IsEngineStopStartEnabled": true,
# 00732:   "IsFuelLevelLow": true,
# 00733:   "IsFuelPortFlapOpen": false,
# 00734:   "RefuelPortPosition": "LEFT_MIDDLE",
# 00735:   "RelativeLevel": 78,
# 00736:   "SupportedFuel": "H2",
# 00737:   "SupportedFuelTypes": "E85",
# 00738:   "TankCapacity": 0.7940143450294365,
# 00739:   "TimeRemaining": 43,
# 00740:   "TractionBattery": {
# 00741:     "AccumulatedChargedEnergy": 0.6735003523705566
# 00742:   },
# 00743:   "AccumulatedChargedThroughput": 0.6188606118542324,
# 00744:   "AccumulatedConsumedEnergy": 0.8182185171290904,
# 00745:   "AccumulatedConsumedThroughput": 0.8318010094502217,
# 00746:   "BatteryConditioning": {
# 00747:     "IsActive": false
# 00748:   },
# 00749:   "IsOngoing": true,
# 00750:   "RequestedMode": "DRIVING_PREPARATION",
# 00751:   "StartTime": "uiusqxkfdp",
# 00752:   "TargetTemperature": 0.864750995357256,
# 00753:   "TargetTime": "edmgdyazdd",
# 00754:   "CellVoltage": {
# 00755:     "CellVoltages": [
# 00756:       0.9588847513008858,
# 00757:       0.09361553954970359
# 00758:     ]
# 00759:   },
# 00760:   "IdMax": 15,
# 00761:   "IdMin": 12,
# 00762:   "Max": 0.6289471644090373,
# 00763:   "Min": 0.625553731853344,
# 00764:   "Charging": {
# 00765:     "AveragePower": 0.5172880910236961
# 00766:   },
# 00767:   "ChargeCurrent": {
# 00768:     "DC": 0.7526252310724201
# 00769:   },
# 00770:   "Phase1": 0.1903836300467192,
# 00771:   "Phase2": 0.1359138851245898,
# 00772:   "Phase3": 0.9732636561014699,
# 00773:   "ChargeLimit": 53,
# 00774:   "ChargePlugType": "IEC_TYPE_1_CCS_DC",
# 00775:   "ChargePortFlap": "OPEN",
# 00776:   "ChargePortPosition": "FRONT_MIDDLE",
# 00777:   "ChargePortType": "TESLA_SUPERCHARGER",
# 00778:   "ChargeRate": 0.42639990728741284,
# 00779:   "ChargeVoltage": {
# 00780:     "DC": 0.5788684711895726
# 00781:   },
# 00782:   "EvseId": "vuiekacuhc",
# 00783:   "IsChargePortFlapOpen": false,
# 00784:   "IsCharging": false,
# 00785:   "IsChargingCableConnected": false,
# 00786:   "IsChargingCableLocked": true,
# 00787:   "IsDischarging": true,
# 00788:   "Location": {
# 00789:     "Altitude": 0.5032828068998398
# 00790:   },
# 00791:   "MaximumChargingCurrent": {
# 00792:     "DC": 0.7644516555940251
# 00793:   },
# 00794:   "PowerLoss": 0.44851359156221715,
# 00795:   "StartStopCharging": "START",
# 00796:   "TimeToComplete": 43,
# 00797:   "Timer": {
# 00798:     "Mode": "START_TIME"
# 00799:   },
# 00800:   "Time": "yephfxhfcy",
# 00801:   "CurrentCurrent": 0.6066140502036551,
# 00802:   "CurrentPower": 0.37135545723375274,
# 00803:   "DCDC": {
# 00804:     "PowerLoss": 0.23242744789466863
# 00805:   },
# 00806:   "ErrorCodes": [
# 00807:     "xhmjfechik",
# 00808:     "nfhsdbmnlb"
# 00809:   ],
# 00810:   "GrossCapacity": 77,
# 00811:   "Id": "vrtwyqvcbm",
# 00812:   "IsGroundConnected": true,
# 00813:   "IsPowerConnected": false,
# 00814:   "MaxVoltage": 25,
# 00815:   "NetCapacity": 43,
# 00816:   "ProductionDate": "rciwuucpuu",
# 00817:   "StateOfCharge": {
# 00818:     "Current": 30.5576118837547
# 00819:   },
# 00820:   "CurrentEnergy": 0.9610104157623743,
# 00821:   "Displayed": 64.00686623926663,
# 00822:   "StateOfHealth": 97.44899414297485,
# 00823:   "Average": 0.885962133865012,
# 00824:   "CellTemperature": [
# 00825:     0.30427873075361545,
# 00826:     0.35689919258316005
# 00827:   ],
# 00828:   "Transmission": {
# 00829:     "ClutchEngagement": 67.45614604186726
# 00830:   },
# 00831:   "ClutchWear": 62,
# 00832:   "CurrentGear": 45,
# 00833:   "DiffLockFrontEngagement": 35.62694365298809,
# 00834:   "DiffLockRearEngagement": 52.83189985464233,
# 00835:   "DriveType": "REAR_WHEEL_DRIVE",
# 00836:   "GearChangeMode": "MANUAL",
# 00837:   "GearCount": -84,
# 00838:   "IsElectricalPowertrainEngaged": false,
# 00839:   "IsLowRangeEngaged": true,
# 00840:   "IsParkLockEngaged": true,
# 00841:   "PerformanceMode": "SPORT",
# 00842:   "SelectedGear": -74,
# 00843:   "TorqueDistribution": 57.541430196569586,
# 00844:   "TravelledDistance": 0.2951626501688511,
# 00845:   "Type": "HYBRID",
# 00846:   "RoofLoad": 84,
# 00847:   "Service": {
# 00848:     "DistanceToService": 0.7070061067709172
# 00849:   },
# 00850:   "IsServiceDue": false,
# 00851:   "TimeToService": 58,
# 00852:   "Trailer": {
# 00853:     "IsConnected": false
# 00854:   },
# 00855:   "TraveledDistance": 0.6742093232400425,
# 00856:   "TraveledDistanceSinceStart": 0.8259209985560608,
# 00857:   "TripDuration": 0.3786194610519995,
# 00858:   "TripMeterReading": 0.8660597997568228,
# 00859:   "TurningDiameter": 22,
# 00860:   "VehicleIdentification": {
# 00861:     "AcrissCode": "plxkmwlvnp"
# 00862:   },
# 00863:   "BodyType": "hhjackogcv",
# 00864:   "Brand": "kqzhbihlrj",
# 00865:   "DateVehicleFirstRegistered": "rzklayagtc",
# 00866:   "KnownVehicleDamages": "gkilaxzowq",
# 00867:   "MeetsEmissionStandard": "sogtvyjgqh",
# 00868:   "Model": "tbdhzmiwir",
# 00869:   "OptionalExtras": [
# 00870:     "yschcgnium",
# 00871:     "otqcgvtkqy",
# 00872:     "jsvsnegqts",
# 00873:     "qvttyfjgey"
# 00874:   ],
# 00875:   "PurchaseDate": "ygloqhszpv",
# 00876:   "VIN": "ccurqvbysa",
# 00877:   "VehicleConfiguration": "cpirgkddzv",
# 00878:   "VehicleExteriorColor": "hnuoxcvffx",
# 00879:   "VehicleInteriorColor": "idjxuehrri",
# 00880:   "VehicleInteriorType": "pdzzyqgasr",
# 00881:   "VehicleModelDate": "fdjcwxvzgx",
# 00882:   "VehicleSeatingCapacity": 82,
# 00883:   "VehicleSpecialUsage": "iqmioscnxp",
# 00884:   "WMI": "vcyjogtpny",
# 00885:   "Year": 63,
# 00886:   "VersionVSS": {
# 00887:     "Label": "foyzsofxwu"
# 00888:   },
# 00889:   "Major": 13,
# 00890:   "Minor": 82,
# 00891:   "Patch": 62,
# 00892:   "Width": 60,
# 00893:   "WidthExcludingMirrors": 19,
# 00894:   "WidthFoldedMirrors": 29,
# 00895:   "WidthIncludingMirrors": 55
# 00896: }

# %%
# Generate random subset (if required)
# small = vss.generate(0.005)
# small.print(2, True)

# %%
# Generate next random dataset based on initial one
# 0.2 : 20% of the data will be changed
second = first.generate_next(0.2)
second.print(2, True)
# Out:
# 00001: {
# 00002:   "Vehicle": {
# 00003:     "ADAS": {
# 00004:       "ABS": {
# 00005:         "IsEnabled": false
# 00006:       }
# 00007:     }
# 00008:   },
# 00009:   "ADAS": {
# 00010:     "ABS": {
# 00011:       "IsEngaged": false
# 00012:     }
# 00013:   },
# 00014:   "ABS": {
# 00015:     "IsError": false
# 00016:   },
# 00017:   "ActiveAutonomyLevel": "unuirdjlva",
# 00018:   "CruiseControl": {
# 00019:     "IsActive": true
# 00020:   },
# 00021:   "IsEnabled": true,
# 00022:   "IsError": true,
# 00023:   "SpeedSet": 0.42242595009084694,
# 00024:   "DMS": {
# 00025:     "IsEnabled": false
# 00026:   },
# 00027:   "IsWarning": false,
# 00028:   "EBA": {
# 00029:     "IsEnabled": false
# 00030:   },
# 00031:   "IsEngaged": true,
# 00032:   "EBD": {
# 00033:     "IsEnabled": false
# 00034:   },
# 00035:   "ESC": {
# 00036:     "IsEnabled": true
# 00037:   },
# 00038:   "IsStrongCrossWindDetected": true,
# 00039:   "RoadFriction": {
# 00040:     "LowerBound": 20.25191170137296
# 00041:   },
# 00042:   "MostProbable": 41.461939552157155,
# 00043:   "UpperBound": 54.70192603489157,
# 00044:   "IsAutoPowerOptimize": false,
# 00045:   "LaneDepartureDetection": {
# 00046:     "IsEnabled": true
# 00047:   },
# 00048:   "ObstacleDetection": {
# 00049:     "IsEnabled": false
# 00050:   },
# 00051:   "PowerOptimizeLevel": 35,
# 00052:   "SupportedAutonomyLevel": "SAE_4",
# 00053:   "TCS": {
# 00054:     "IsEnabled": false
# 00055:   },
# 00056:   "Acceleration": {
# 00057:     "Lateral": 0.8711425245136046
# 00058:   },
# 00059:   "Longitudinal": 0.8909419878935876,
# 00060:   "Vertical": 0.6508600798764044,
# 00061:   "AngularVelocity": {
# 00062:     "Pitch": 0.4763631781558625
# 00063:   },
# 00064:   "Roll": 0.788940110897309,
# 00065:   "Yaw": 0.7629865900023821,
# 00066:   "AverageSpeed": 0.44339237694281786,
# 00067:   "Body": {
# 00068:     "BodyType": "ixkmuivwlk"
# 00069:   },
# 00070:   "Hood": {
# 00071:     "IsOpen": true
# 00072:   },
# 00073:   "Position": 92,
# 00074:   "Switch": "CLOSE",
# 00075:   "Horn": {
# 00076:     "IsActive": true
# 00077:   },
# 00078:   "Lights": {
# 00079:     "Backup": {
# 00080:       "IsDefect": false
# 00081:     }
# 00082:   },
# 00083:   "Backup": {
# 00084:     "IsOn": false
# 00085:   },
# 00086:   "Beam": {
# 00087:     "High": {
# 00088:       "IsDefect": false
# 00089:     }
# 00090:   },
# 00091:   "High": {
# 00092:     "IsOn": true
# 00093:   },
# 00094:   "Low": {
# 00095:     "IsDefect": true
# 00096:   },
# 00097:   "IsOn": true,
# 00098:   "Brake": {
# 00099:     "IsActive": "ADAPTIVE"
# 00100:   },
# 00101:   "IsDefect": true,
# 00102:   "DirectionIndicator": {
# 00103:     "Left": {
# 00104:       "IsDefect": true
# 00105:     }
# 00106:   },
# 00107:   "Left": {
# 00108:     "IsSignaling": true
# 00109:   },
# 00110:   "Right": {
# 00111:     "IsDefect": false
# 00112:   },
# 00113:   "IsSignaling": false,
# 00114:   "Fog": {
# 00115:     "Front": {
# 00116:       "IsDefect": false
# 00117:     }
# 00118:   },
# 00119:   "Front": {
# 00120:     "IsOn": false
# 00121:   },
# 00122:   "Rear": {
# 00123:     "IsDefect": false
# 00124:   },
# 00125:   "Hazard": {
# 00126:     "IsDefect": true
# 00127:   },
# 00128:   "IsHighBeamSwitchOn": true,
# 00129:   "LicensePlate": "vlrzwcujei",
# 00130:   "LightSwitch": "OFF",
# 00131:   "Parking": {
# 00132:     "IsDefect": true
# 00133:   },
# 00134:   "Running": {
# 00135:     "IsDefect": false
# 00136:   },
# 00137:   "Mirrors": {
# 00138:     "DriverSide": {
# 00139:       "IsFolded": true
# 00140:     }
# 00141:   },
# 00142:   "DriverSide": {
# 00143:     "IsHeatingOn": false
# 00144:   },
# 00145:   "IsLocked": true,
# 00146:   "Pan": 2,
# 00147:   "Tilt": 56,
# 00148:   "PassengerSide": {
# 00149:     "IsFolded": false
# 00150:   },
# 00151:   "IsHeatingOn": false,
# 00152:   "Raindetection": {
# 00153:     "Intensity": 74
# 00154:   },
# 00155:   "RearMainSpoilerPosition": 0.938595296854674,
# 00156:   "RefuelPosition": "FRONT_LEFT",
# 00157:   "Trunk": {
# 00158:     "Front": {
# 00159:       "IsLightOn": false
# 00160:     }
# 00161:   },
# 00162:   "IsOpen": false,
# 00163:   "IsLightOn": true,
# 00164:   "Windshield": {
# 00165:     "Front": {
# 00166:       "IsHeatingOn": false
# 00167:     }
# 00168:   },
# 00169:   "WasherFluid": {
# 00170:     "IsLevelLow": false
# 00171:   },
# 00172:   "Level": "NORMAL",
# 00173:   "Wiping": {
# 00174:     "Intensity": 50
# 00175:   },
# 00176:   "IsWipersWorn": true,
# 00177:   "Mode": "MANUAL",
# 00178:   "System": {
# 00179:     "ActualPosition": 0.2596638086033797
# 00180:   },
# 00181:   "DriveCurrent": 0.7140579774423442,
# 00182:   "Frequency": 44,
# 00183:   "IsBlocked": true,
# 00184:   "IsEndingWipeCycle": false,
# 00185:   "IsOverheated": false,
# 00186:   "IsPositionReached": true,
# 00187:   "IsWiperError": false,
# 00188:   "IsWiping": true,
# 00189:   "TargetPosition": 0.0442402207801782,
# 00190:   "WiperWear": 66,
# 00191:   "IsLevelLow": true,
# 00192:   "Intensity": 70,
# 00193:   "ActualPosition": 0.1705006767954308,
# 00194:   "Cabin": {
# 00195:     "Convertible": {
# 00196:       "Status": "CLOSED"
# 00197:     }
# 00198:   },
# 00199:   "Door": {
# 00200:     "Row1": {
# 00201:       "DriverSide": {
# 00202:         "IsChildLockActive": false
# 00203:       }
# 00204:     }
# 00205:   },
# 00206:   "Row1": {
# 00207:     "DriverSide": {
# 00208:       "IsLocked": true
# 00209:     }
# 00210:   },
# 00211:   "Shade": {
# 00212:     "IsOpen": false
# 00213:   },
# 00214:   "Window": {
# 00215:     "IsOpen": false
# 00216:   },
# 00217:   "IsChildLockActive": true,
# 00218:   "Row2": {
# 00219:     "DriverSide": {
# 00220:       "IsChildLockActive": true
# 00221:     }
# 00222:   },
# 00223:   "DoorCount": 100,
# 00224:   "DriverPosition": "tcyscaiols",
# 00225:   "HVAC": {
# 00226:     "AmbientAirTemperature": 0.3325706115176509
# 00227:   },
# 00228:   "IsAirConditioningActive": true,
# 00229:   "IsFrontDefrosterActive": true,
# 00230:   "IsRearDefrosterActive": false,
# 00231:   "IsRecirculationActive": false,
# 00232:   "Station": {
# 00233:     "Row1": {
# 00234:       "Driver": {
# 00235:         "AirDistribution": "MIDDLE"
# 00236:       }
# 00237:     }
# 00238:   },
# 00239:   "Driver": {
# 00240:     "FanSpeed": 47
# 00241:   },
# 00242:   "Temperature": 19,
# 00243:   "Passenger": {
# 00244:     "AirDistribution": "MIDDLE"
# 00245:   },
# 00246:   "FanSpeed": 39,
# 00247:   "AirDistribution": "DOWN",
# 00248:   "Row3": {
# 00249:     "Driver": {
# 00250:       "AirDistribution": "crmapsybym"
# 00251:     }
# 00252:   },
# 00253:   "Row4": {
# 00254:     "Driver": {
# 00255:       "AirDistribution": "UP"
# 00256:     }
# 00257:   },
# 00258:   "Infotainment": {
# 00259:     "HMI": {
# 00260:       "Brightness": 70.24516237526844
# 00261:     }
# 00262:   },
# 00263:   "HMI": {
# 00264:     "CurrentLanguage": "ckpwqfybpi"
# 00265:   },
# 00266:   "DateFormat": "MM_DD_YYYY",
# 00267:   "DayNightMode": "DAY",
# 00268:   "DisplayOffDuration": 56,
# 00269:   "DistanceUnit": "MILES",
# 00270:   "EVEconomyUnits": "WATT_HOURS_PER_MILE",
# 00271:   "EVEnergyUnits": "AMPERE_HOURS",
# 00272:   "FontSize": "LARGE",
# 00273:   "FuelEconomyUnits": "LITERS_PER_100_KILOMETERS",
# 00274:   "FuelVolumeUnit": "raabcxjlbg",
# 00275:   "IsScreenAlwaysOn": false,
# 00276:   "LastActionTime": "hounoofwbq",
# 00277:   "SpeedUnit": "KILOMETERS_PER_HOUR",
# 00278:   "TemperatureUnit": "F",
# 00279:   "TimeFormat": "HR_12",
# 00280:   "TirePressureUnit": "KPA",
# 00281:   "Media": {
# 00282:     "Action": "UNKNOWN"
# 00283:   },
# 00284:   "DeclinedURI": "joicprqkue",
# 00285:   "Played": {
# 00286:     "Album": "dqmqjfdxwv"
# 00287:   },
# 00288:   "Artist": "urbfrvgleq",
# 00289:   "PlaybackRate": 0.053884377262307326,
# 00290:   "Source": "hpqqcpevre",
# 00291:   "Track": "vwitqqkzda",
# 00292:   "URI": "cyzgdzwfyf",
# 00293:   "SelectedURI": "pcekonesqm",
# 00294:   "Volume": 22,
# 00295:   "Navigation": {
# 00296:     "DestinationSet": {
# 00297:       "Latitude": 0.3839402721827986
# 00298:     }
# 00299:   },
# 00300:   "DestinationSet": {
# 00301:     "Longitude": 0.24268404668883825
# 00302:   },
# 00303:   "GuidanceVoice": "ETC",
# 00304:   "Map": {
# 00305:     "IsAutoScaleModeUsed": true
# 00306:   },
# 00307:   "Mute": "ALERT_ONLY",
# 00308:   "SmartphoneProjection": {
# 00309:     "Active": "ACTIVE"
# 00310:   },
# 00311:   "SupportedMode": "APPLE_CARPLAY",
# 00312:   "SmartphoneScreenMirroring": {
# 00313:     "Active": "ACTIVE"
# 00314:   },
# 00315:   "IsWindowChildLockEngaged": false,
# 00316:   "Light": {
# 00317:     "AmbientLight": {
# 00318:       "Row1": {
# 00319:         "DriverSide": {
# 00320:           "Color": "msomwzntpu"
# 00321:         }
# 00322:       }
# 00323:     }
# 00324:   },
# 00325:   "AmbientLight": {
# 00326:     "Row1": {
# 00327:       "DriverSide": {
# 00328:         "Intensity": 76
# 00329:       }
# 00330:     }
# 00331:   },
# 00332:   "Color": "vzftubiqey",
# 00333:   "InteractiveLightBar": {
# 00334:     "Color": "ucjpqzqimj"
# 00335:   },
# 00336:   "Effect": "byiswhpbqq",
# 00337:   "IsDomeOn": true,
# 00338:   "IsGloveBoxOn": false,
# 00339:   "PerceivedAmbientLight": 0,
# 00340:   "Spotlight": {
# 00341:     "Row1": {
# 00342:       "DriverSide": {
# 00343:         "Color": "phpjeifhaw"
# 00344:       }
# 00345:     }
# 00346:   },
# 00347:   "RearShade": {
# 00348:     "IsOpen": false
# 00349:   },
# 00350:   "RearviewMirror": {
# 00351:     "DimmingLevel": 44
# 00352:   },
# 00353:   "Seat": {
# 00354:     "Row1": {
# 00355:       "DriverSide": {
# 00356:         "Airbag": {
# 00357:           "IsDeployed": false
# 00358:         }
# 00359:       }
# 00360:     }
# 00361:   },
# 00362:   "Backrest": {
# 00363:     "Lumbar": {
# 00364:       "Height": 34
# 00365:     }
# 00366:   },
# 00367:   "Lumbar": {
# 00368:     "Support": 30.521762989163737
# 00369:   },
# 00370:   "Recline": 0.2764398712085626,
# 00371:   "SideBolster": {
# 00372:     "Support": 8.7469153965536
# 00373:   },
# 00374:   "Headrest": {
# 00375:     "Angle": 0.8900558502101554
# 00376:   },
# 00377:   "Height": 4,
# 00378:   "Heating": 86,
# 00379:   "HeatingCooling": 1,
# 00380:   "IsBelted": false,
# 00381:   "IsOccupied": false,
# 00382:   "Massage": 73,
# 00383:   "Occupant": {
# 00384:     "Identifier": {
# 00385:       "Issuer": "ymejzmhupm"
# 00386:     }
# 00387:   },
# 00388:   "Identifier": {
# 00389:     "Subject": "unmmoyyqvx"
# 00390:   },
# 00391:   "SeatBeltHeight": 54,
# 00392:   "Seating": {
# 00393:     "Length": 41
# 00394:   },
# 00395:   "IsReclineBackwardEngaged": true,
# 00396:   "IsReclineForwardEngaged": true,
# 00397:   "IsDownEngaged": true,
# 00398:   "IsLessSupportEngaged": false,
# 00399:   "IsMoreSupportEngaged": true,
# 00400:   "IsUpEngaged": true,
# 00401:   "IsBackwardEngaged": false,
# 00402:   "IsForwardEngaged": true,
# 00403:   "IsCoolerEngaged": true,
# 00404:   "IsTiltBackwardEngaged": false,
# 00405:   "IsTiltForwardEngaged": true,
# 00406:   "IsWarmerEngaged": false,
# 00407:   "IsDecreaseEngaged": false,
# 00408:   "IsIncreaseEngaged": false,
# 00409:   "Middle": {
# 00410:     "Airbag": {
# 00411:       "IsDeployed": true
# 00412:     }
# 00413:   },
# 00414:   "Support": 47.03683451261803,
# 00415:   "Angle": 0.3231054580011058,
# 00416:   "Issuer": "tlkdyzddfa",
# 00417:   "Subject": "qcxpgwvveb",
# 00418:   "Length": 76,
# 00419:   "Airbag": {
# 00420:     "IsDeployed": false
# 00421:   },
# 00422:   "IsDeployed": true,
# 00423:   "SeatPosCount": [
# 00424:     14,
# 00425:     53,
# 00426:     88,
# 00427:     4
# 00428:   ],
# 00429:   "SeatRowCount": 6,
# 00430:   "Sunroof": {
# 00431:     "Position": 52
# 00432:   },
# 00433:   "CargoVolume": 0.23204320766695763,
# 00434:   "Chassis": {
# 00435:     "Accelerator": {
# 00436:       "PedalPosition": 96
# 00437:     }
# 00438:   },
# 00439:   "Axle": {
# 00440:     "Row1": {
# 00441:       "AxleWidth": 97
# 00442:     }
# 00443:   },
# 00444:   "SteeringAngle": 0.9142314385229335,
# 00445:   "TireAspectRatio": 93,
# 00446:   "TireDiameter": 0.7884211134506436,
# 00447:   "TireWidth": 33,
# 00448:   "TrackWidth": 87,
# 00449:   "TreadWidth": 26,
# 00450:   "Wheel": {
# 00451:     "Left": {
# 00452:       "AngularSpeed": 0.007828115974766736
# 00453:     }
# 00454:   },
# 00455:   "FluidLevel": 67,
# 00456:   "IsBrakesWorn": true,
# 00457:   "IsFluidLevelLow": true,
# 00458:   "PadWear": 80,
# 00459:   "Speed": 0.5614743019994328,
# 00460:   "Tire": {
# 00461:     "IsPressureLow": true
# 00462:   },
# 00463:   "Pressure": 46,
# 00464:   "AngularSpeed": 0.5575073192399513,
# 00465:   "IsPressureLow": true,
# 00466:   "WheelCount": 5,
# 00467:   "WheelDiameter": 0.635507721318149,
# 00468:   "WheelWidth": 0.17377898994719898,
# 00469:   "AxleWidth": 13,
# 00470:   "AxleCount": 4,
# 00471:   "IsDriverEmergencyBrakingDetected": true,
# 00472:   "PedalPosition": 16,
# 00473:   "ParkingBrake": {
# 00474:     "IsAutoApplyEnabled": false
# 00475:   },
# 00476:   "SteeringWheel": {
# 00477:     "Angle": -26
# 00478:   },
# 00479:   "Extension": 15,
# 00480:   "Wheelbase": 62,
# 00481:   "Connectivity": {
# 00482:     "IsConnectivityAvailable": false
# 00483:   },
# 00484:   "CurbWeight": 63,
# 00485:   "CurrentLocation": {
# 00486:     "Altitude": 0.8297770370082465
# 00487:   },
# 00488:   "GNSSReceiver": {
# 00489:     "FixType": "THREE_D_SATELLITE_AND_GROUND_BASED_AUGMENTATION"
# 00490:   },
# 00491:   "MountingPosition": {
# 00492:     "X": 62
# 00493:   },
# 00494:   "Y": 73,
# 00495:   "Z": -16,
# 00496:   "Heading": 0.906773164155177,
# 00497:   "HorizontalAccuracy": 0.9298393144373516,
# 00498:   "Latitude": 0.670425835413727,
# 00499:   "Longitude": 0.5730612987203597,
# 00500:   "Timestamp": "maiffapnra",
# 00501:   "VerticalAccuracy": 0.6264916786996301,
# 00502:   "CurrentOverallWeight": 48,
# 00503:   "Diagnostics": {
# 00504:     "DTCCount": 31
# 00505:   },
# 00506:   "DTCList": [
# 00507:     "kbvujiaujs",
# 00508:     "wmuqetndfj",
# 00509:     "qiypxhcndi",
# 00510:     "tcqbcwbtaw"
# 00511:   ],
# 00512:   "AttentiveProbability": 34.67412673760607,
# 00513:   "DistractionLevel": 70.79703135223015,
# 00514:   "FatigueLevel": 0.9951653668153885,
# 00515:   "HeartRate": 57,
# 00516:   "IsEyesOnRoad": false,
# 00517:   "IsHandsOnWheel": false,
# 00518:   "EmissionsCO2": 77,
# 00519:   "Exterior": {
# 00520:     "AirTemperature": 0.020686980470541294
# 00521:   },
# 00522:   "Humidity": 45.35630056538689,
# 00523:   "LightIntensity": 71.8407938384064,
# 00524:   "GrossWeight": 52,
# 00525:   "IsBrokenDown": true,
# 00526:   "IsMoving": true,
# 00527:   "LowVoltageBattery": {
# 00528:     "CurrentCurrent": 0.9237752618932208
# 00529:   },
# 00530:   "CurrentVoltage": 0.7757178545433862,
# 00531:   "NominalCapacity": 7,
# 00532:   "NominalVoltage": 2,
# 00533:   "LowVoltageSystemState": "UNDEFINED",
# 00534:   "MaxTowBallWeight": 86,
# 00535:   "MaxTowWeight": 54,
# 00536:   "OBD": {
# 00537:     "AbsoluteLoad": 0.15453851928171636
# 00538:   },
# 00539:   "AcceleratorPositionD": 68.58565474834501,
# 00540:   "AcceleratorPositionE": 58.759085188653295,
# 00541:   "AcceleratorPositionF": 0.03462068170990562,
# 00542:   "AirStatus": "leidxesfnp",
# 00543:   "AmbientAirTemperature": 0.7536778078658692,
# 00544:   "BarometricPressure": 0.13447191800196334,
# 00545:   "Catalyst": {
# 00546:     "Bank1": {
# 00547:       "Temperature1": 0.1967569362106515
# 00548:     }
# 00549:   },
# 00550:   "Bank1": {
# 00551:     "Temperature2": 0.8167012014064507
# 00552:   },
# 00553:   "Bank2": {
# 00554:     "Temperature1": 0.23283518712115203
# 00555:   },
# 00556:   "Temperature2": 0.04398388834024636,
# 00557:   "CommandedEGR": 56.16646967024076,
# 00558:   "CommandedEVAP": 0.7621490977911433,
# 00559:   "CommandedEquivalenceRatio": 0.9854865191812383,
# 00560:   "ControlModuleVoltage": 0.9914139655006884,
# 00561:   "CoolantTemperature": 0.18992341771608756,
# 00562:   "DistanceSinceDTCClear": 0.554233464647845,
# 00563:   "DistanceWithMIL": 0.9028761085941921,
# 00564:   "DriveCycleStatus": {
# 00565:     "DTCCount": 78
# 00566:   },
# 00567:   "IgnitionType": "COMPRESSION",
# 00568:   "IsMILOn": true,
# 00569:   "EGRError": 28.051498597088266,
# 00570:   "EVAPVaporPressure": 0.01643662964917192,
# 00571:   "EVAPVaporPressureAbsolute": 0.28017225396549594,
# 00572:   "EVAPVaporPressureAlternate": 0.9857743092871849,
# 00573:   "EngineLoad": 89.38280673757573,
# 00574:   "EngineSpeed": 0.0961900890145524,
# 00575:   "EthanolPercent": 0.686886088217332,
# 00576:   "FreezeDTC": "iwabrlikdf",
# 00577:   "FuelInjectionTiming": 0.10452175938693009,
# 00578:   "FuelLevel": 27.703446876985637,
# 00579:   "FuelPressure": 0.7574897560576961,
# 00580:   "FuelRailPressureAbsolute": 0.7763812832084002,
# 00581:   "FuelRailPressureDirect": 0.3874424783924125,
# 00582:   "FuelRailPressureVac": 0.842891635170489,
# 00583:   "FuelRate": 0.43926392941717707,
# 00584:   "FuelStatus": "uiwxxxfxnk",
# 00585:   "FuelType": 59,
# 00586:   "HybridBatteryRemaining": 94.1608993396703,
# 00587:   "IntakeTemp": 0.6615758677387363,
# 00588:   "IsPTOActive": false,
# 00589:   "LongTermFuelTrim1": 85.03412854232293,
# 00590:   "LongTermFuelTrim2": 0.016321005593117555,
# 00591:   "LongTermO2Trim1": 58.14043893149432,
# 00592:   "LongTermO2Trim2": 0.49523627334382525,
# 00593:   "LongTermO2Trim3": 89.3267426249634,
# 00594:   "LongTermO2Trim4": 33.571969628657975,
# 00595:   "MAF": 54,
# 00596:   "MAP": 52,
# 00597:   "MaxMAF": 0.9141141403567303,
# 00598:   "O2": {
# 00599:     "Sensor1": {
# 00600:       "ShortTermFuelTrim": 0.151034139155782
# 00601:     }
# 00602:   },
# 00603:   "Sensor1": {
# 00604:     "Voltage": 0.05310858657148254
# 00605:   },
# 00606:   "Sensor2": {
# 00607:     "ShortTermFuelTrim": 23.870973328343503
# 00608:   },
# 00609:   "Voltage": 0.12816965355598964,
# 00610:   "Sensor3": {
# 00611:     "ShortTermFuelTrim": 66.33632588779169
# 00612:   },
# 00613:   "Sensor4": {
# 00614:     "ShortTermFuelTrim": 56.937460388974706
# 00615:   },
# 00616:   "Sensor5": {
# 00617:     "ShortTermFuelTrim": 7.143613275119886
# 00618:   },
# 00619:   "Sensor6": {
# 00620:     "ShortTermFuelTrim": 18.116805432069892
# 00621:   },
# 00622:   "Sensor7": {
# 00623:     "ShortTermFuelTrim": 24.784371179978837
# 00624:   },
# 00625:   "Sensor8": {
# 00626:     "ShortTermFuelTrim": 47.66226904766615
# 00627:   },
# 00628:   "O2WR": {
# 00629:     "Sensor1": {
# 00630:       "Current": 0.39386873867777195
# 00631:     }
# 00632:   },
# 00633:   "Lambda": 0.30590241367773896,
# 00634:   "Current": 0.6594610062647946,
# 00635:   "OBDStandards": 16,
# 00636:   "OilTemperature": 0.5810564263009992,
# 00637:   "OxygenSensorsIn2Banks": 50,
# 00638:   "OxygenSensorsIn4Banks": 34,
# 00639:   "PidsA": "1C",
# 00640:   "PidsB": "wzsutstwjh",
# 00641:   "PidsC": "48",
# 00642:   "RelativeAcceleratorPosition": 91.07288689161126,
# 00643:   "RelativeThrottlePosition": 67.85835486128123,
# 00644:   "RunTime": 0.376024920402803,
# 00645:   "RunTimeMIL": 0.8906936832432695,
# 00646:   "ShortTermFuelTrim1": 93.10236327128473,
# 00647:   "ShortTermFuelTrim2": 84.77972027816676,
# 00648:   "ShortTermO2Trim1": 13.021210580830944,
# 00649:   "ShortTermO2Trim2": 46.127519593178214,
# 00650:   "ShortTermO2Trim3": 84.07716215969847,
# 00651:   "ShortTermO2Trim4": 67.34431436729834,
# 00652:   "Status": {
# 00653:     "DTCCount": 28
# 00654:   },
# 00655:   "ThrottleActuator": 1.3906618478059296,
# 00656:   "ThrottlePosition": 93.22033547978815,
# 00657:   "ThrottlePositionB": 71.08763187277016,
# 00658:   "ThrottlePositionC": 0.2780693338031591,
# 00659:   "TimeSinceDTCCleared": 0.31129283510870387,
# 00660:   "TimingAdvance": 0.8042689041627058,
# 00661:   "WarmupsSinceDTCClear": 67,
# 00662:   "HeadPosition": {
# 00663:     "Pitch": 0.32498908973836915
# 00664:   },
# 00665:   "X": 16,
# 00666:   "MidEyeGaze": {
# 00667:     "Azimuth": 0.0642451917531417
# 00668:   },
# 00669:   "Elevation": 0.7239356863129064,
# 00670:   "Pitch": 0.6669270427535521,
# 00671:   "Azimuth": 0.9825266714077051,
# 00672:   "Powertrain": {
# 00673:     "AccumulatedBrakingEnergy": 0.921432093599458
# 00674:   },
# 00675:   "CombustionEngine": {
# 00676:     "AspirationType": "NATURAL"
# 00677:   },
# 00678:   "Bore": 0.9968235406002539,
# 00679:   "CompressionRatio": "ypxqalxkfy",
# 00680:   "Configuration": "SQUARE",
# 00681:   "DieselExhaustFluid": {
# 00682:     "Capacity": 0.5509677648485015
# 00683:   },
# 00684:   "Range": 78,
# 00685:   "DieselParticulateFilter": {
# 00686:     "DeltaPressure": 0.3164281958299394
# 00687:   },
# 00688:   "InletTemperature": 0.577559099089194,
# 00689:   "OutletTemperature": 0.6805616824579959,
# 00690:   "Displacement": 63,
# 00691:   "ECT": 98,
# 00692:   "EOP": 36,
# 00693:   "EOT": 60,
# 00694:   "EngineCode": "wuckmzwyud",
# 00695:   "EngineCoolant": {
# 00696:     "Capacity": 0.8412211741868943
# 00697:   },
# 00698:   "LifeRemaining": -9,
# 00699:   "EngineCoolantCapacity": 0.20363321376375543,
# 00700:   "EngineHours": 0.0139120745536504,
# 00701:   "EngineOil": {
# 00702:     "Capacity": 0.3477819651456522
# 00703:   },
# 00704:   "EngineOilCapacity": 0.14877628843634894,
# 00705:   "EngineOilLevel": "CRITICALLY_LOW",
# 00706:   "IdleHours": 0.08502904789699217,
# 00707:   "IsRunning": false,
# 00708:   "MaxPower": 0.8612862704423802,
# 00709:   "MaxTorque": 52,
# 00710:   "NumberOfCylinders": 53,
# 00711:   "NumberOfValvesPerCylinder": 97,
# 00712:   "OilLifeRemaining": 16,
# 00713:   "Power": 45,
# 00714:   "StrokeLength": 0.07551884231816985,
# 00715:   "TPS": 28,
# 00716:   "Torque": 94,
# 00717:   "ElectricMotor": {
# 00718:     "CoolantTemperature": 0
# 00719:   },
# 00720:   "Capacity": 0.6734946747848796,
# 00721:   "MaxRegenPower": 5,
# 00722:   "MaxRegenTorque": 38,
# 00723:   "TimeInUse": 0.005383619938544193,
# 00724:   "FuelSystem": {
# 00725:     "AbsoluteLevel": 0.37715712108170085
# 00726:   },
# 00727:   "AverageConsumption": 0.7536935597044833,
# 00728:   "ConsumptionSinceStart": 0.7890852641371363,
# 00729:   "HybridType": "CIMG",
# 00730:   "InstantConsumption": 0.6585714936792711,
# 00731:   "IsEngineStopStartEnabled": false,
# 00732:   "IsFuelLevelLow": true,
# 00733:   "IsFuelPortFlapOpen": true,
# 00734:   "RefuelPortPosition": "LEFT_MIDDLE",
# 00735:   "RelativeLevel": 96,
# 00736:   "SupportedFuel": "H2",
# 00737:   "SupportedFuelTypes": "E85",
# 00738:   "TankCapacity": 0.7940143450294365,
# 00739:   "TimeRemaining": 43,
# 00740:   "TractionBattery": {
# 00741:     "AccumulatedChargedEnergy": 0.6735003523705566
# 00742:   },
# 00743:   "AccumulatedChargedThroughput": 0.6188606118542324,
# 00744:   "AccumulatedConsumedEnergy": 0.8182185171290904,
# 00745:   "AccumulatedConsumedThroughput": 0.905616202384959,
# 00746:   "BatteryConditioning": {
# 00747:     "IsActive": false
# 00748:   },
# 00749:   "IsOngoing": true,
# 00750:   "RequestedMode": "ckhsgyqqrd",
# 00751:   "StartTime": "uiusqxkfdp",
# 00752:   "TargetTemperature": 0.864750995357256,
# 00753:   "TargetTime": "edmgdyazdd",
# 00754:   "CellVoltage": {
# 00755:     "CellVoltages": [
# 00756:       0.9588847513008858,
# 00757:       0.09361553954970359
# 00758:     ]
# 00759:   },
# 00760:   "CellVoltages": [
# 00761:     0.9588847513008858,
# 00762:     0.09361553954970359
# 00763:   ],
# 00764:   "IdMax": 15,
# 00765:   "IdMin": 12,
# 00766:   "Max": 0.6289471644090373,
# 00767:   "Min": 0.625553731853344,
# 00768:   "Charging": {
# 00769:     "AveragePower": 0.5172880910236961
# 00770:   },
# 00771:   "ChargeCurrent": {
# 00772:     "DC": 0.7526252310724201
# 00773:   },
# 00774:   "Phase1": 0.6683587403887615,
# 00775:   "Phase2": 0.1359138851245898,
# 00776:   "Phase3": 0.9732636561014699,
# 00777:   "ChargeLimit": 53,
# 00778:   "ChargePlugType": "xjwpnzapfg",
# 00779:   "ChargePortFlap": "ritmjdasqy",
# 00780:   "ChargePortPosition": "FRONT_MIDDLE",
# 00781:   "ChargePortType": "myptavzina",
# 00782:   "ChargeRate": 0.42639990728741284,
# 00783:   "ChargeVoltage": {
# 00784:     "DC": 0.5788684711895726
# 00785:   },
# 00786:   "EvseId": "vuiekacuhc",
# 00787:   "IsChargePortFlapOpen": true,
# 00788:   "IsCharging": false,
# 00789:   "IsChargingCableConnected": true,
# 00790:   "IsChargingCableLocked": true,
# 00791:   "IsDischarging": true,
# 00792:   "Location": {
# 00793:     "Altitude": 0.5032828068998398
# 00794:   },
# 00795:   "MaximumChargingCurrent": {
# 00796:     "DC": 0.7644516555940251
# 00797:   },
# 00798:   "PowerLoss": 0.44851359156221715,
# 00799:   "StartStopCharging": "START",
# 00800:   "TimeToComplete": 18,
# 00801:   "Timer": {
# 00802:     "Mode": "START_TIME"
# 00803:   },
# 00804:   "Time": "yephfxhfcy",
# 00805:   "CurrentCurrent": 0.6066140502036551,
# 00806:   "CurrentPower": 0.37135545723375274,
# 00807:   "DCDC": {
# 00808:     "PowerLoss": 0.23242744789466863
# 00809:   },
# 00810:   "ErrorCodes": [
# 00811:     "xhmjfechik",
# 00812:     "nfhsdbmnlb"
# 00813:   ],
# 00814:   "GrossCapacity": 77,
# 00815:   "Id": "vrtwyqvcbm",
# 00816:   "IsGroundConnected": true,
# 00817:   "IsPowerConnected": false,
# 00818:   "MaxVoltage": 25,
# 00819:   "NetCapacity": 43,
# 00820:   "ProductionDate": "apqatgrvqy",
# 00821:   "StateOfCharge": {
# 00822:     "Current": 30.5576118837547
# 00823:   },
# 00824:   "CurrentEnergy": 0.7432527300436415,
# 00825:   "Displayed": 64.00686623926663,
# 00826:   "StateOfHealth": 97.44899414297485,
# 00827:   "Average": 0.885962133865012,
# 00828:   "CellTemperature": [
# 00829:     0.30427873075361545,
# 00830:     0.35689919258316005
# 00831:   ],
# 00832:   "Transmission": {
# 00833:     "ClutchEngagement": 67.45614604186726
# 00834:   },
# 00835:   "ClutchWear": 62,
# 00836:   "CurrentGear": 45,
# 00837:   "DiffLockFrontEngagement": 35.62694365298809,
# 00838:   "DiffLockRearEngagement": 52.83189985464233,
# 00839:   "DriveType": "bttomfmfxy",
# 00840:   "GearChangeMode": "spqtwlrqqt",
# 00841:   "GearCount": -84,
# 00842:   "IsElectricalPowertrainEngaged": false,
# 00843:   "IsLowRangeEngaged": true,
# 00844:   "IsParkLockEngaged": true,
# 00845:   "PerformanceMode": "SPORT",
# 00846:   "SelectedGear": -74,
# 00847:   "TorqueDistribution": 57.541430196569586,
# 00848:   "TravelledDistance": 0.2951626501688511,
# 00849:   "Type": "HYBRID",
# 00850:   "RoofLoad": 84,
# 00851:   "Service": {
# 00852:     "DistanceToService": 0.7070061067709172
# 00853:   },
# 00854:   "IsServiceDue": false,
# 00855:   "TimeToService": 58,
# 00856:   "Trailer": {
# 00857:     "IsConnected": true
# 00858:   },
# 00859:   "TraveledDistance": 0.9645431699112383,
# 00860:   "TraveledDistanceSinceStart": 0.5728455425507173,
# 00861:   "TripDuration": 0.3786194610519995,
# 00862:   "TripMeterReading": 0.2612111783749961,
# 00863:   "TurningDiameter": 95,
# 00864:   "VehicleIdentification": {
# 00865:     "AcrissCode": "plxkmwlvnp"
# 00866:   },
# 00867:   "BodyType": "vazzrmbdzc",
# 00868:   "Brand": "kqzhbihlrj",
# 00869:   "DateVehicleFirstRegistered": "xzzyqpzgul",
# 00870:   "KnownVehicleDamages": "gkilaxzowq",
# 00871:   "MeetsEmissionStandard": "sogtvyjgqh",
# 00872:   "Model": "mybsgibmjq",
# 00873:   "OptionalExtras": [
# 00874:     "yschcgnium",
# 00875:     "otqcgvtkqy",
# 00876:     "jsvsnegqts",
# 00877:     "qvttyfjgey"
# 00878:   ],
# 00879:   "PurchaseDate": "ygloqhszpv",
# 00880:   "VIN": "ccurqvbysa",
# 00881:   "VehicleConfiguration": "cpirgkddzv",
# 00882:   "VehicleExteriorColor": "hnuoxcvffx",
# 00883:   "VehicleInteriorColor": "idjxuehrri",
# 00884:   "VehicleInteriorType": "pdzzyqgasr",
# 00885:   "VehicleModelDate": "fdjcwxvzgx",
# 00886:   "VehicleSeatingCapacity": 34,
# 00887:   "VehicleSpecialUsage": "iqmioscnxp",
# 00888:   "WMI": "pmmgbknisy",
# 00889:   "Year": 72,
# 00890:   "VersionVSS": {
# 00891:     "Label": "foyzsofxwu"
# 00892:   },
# 00893:   "Major": 13,
# 00894:   "Minor": 82,
# 00895:   "Patch": 62,
# 00896:   "Width": 60,
# 00897:   "WidthExcludingMirrors": 19,
# 00898:   "WidthFoldedMirrors": 29,
# 00899:   "WidthIncludingMirrors": 55
# 00900: }

# %%
# Save to file
first.save('./first.json')
second.save('./second.json')
